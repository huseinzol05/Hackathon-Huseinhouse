# %%
import re
import tensorflow as tf
import numpy as np
import time
import os
import collections
import random
import nltk
import time
import pickle

# %%
def clearstring(string):
    string = re.sub('[^A-Za-z\- ]+', '', string)
    string = string.split(' ')
    string = filter(None, string)
    string = [y.strip() for y in string]
    return [y.lower() for y in string if len(y) > 3 and y.find('nbsp') < 0]

def build_dataset(words, n_words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(n_words - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        index = dictionary.get(word, 0)
        if index == 0:  # dictionary['UNK']
            unk_count += 1
        data.append(index)
    count[0][1] = unk_count
    reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reversed_dictionary

data_index = 0

# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    global data
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1  # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    if data_index + span > len(data):
        data_index = 0
    buffer.extend(data[data_index:data_index + span])
    data_index += span
    for i in range(batch_size // num_skips):
        context_words = [w for w in range(span) if w != skip_window]
        words_to_use = random.sample(context_words, num_skips)
        for j, context_word in enumerate(words_to_use):
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[context_word]
        if data_index == len(data):
            for word in data[:span]:
                buffer.append(word)
            data_index = span
        else:
            buffer.append(data[data_index])
            data_index += 1
    # Backtrack a little bit to avoid skipping words in the end of a batch
    data_index = (data_index + len(data) - span) % len(data)
    return batch, labels

# %%
with open('books/Sorcerer\'s-Stone.txt', 'r',encoding = "ISO-8859-1") as fopen:
    vocabulary = clearstring(' '.join(nltk.word_tokenize(fopen.read())))
print('example 10 words:',vocabulary[:10])
print('size corpus:',len(vocabulary))
vocabulary_size = len(list(set(vocabulary)))
print('size of unique words:',vocabulary_size)
dimension = 128
skip_window = 1
num_skips = 2
batch_size = 64
location = os.getcwd()
# Out:
# example 10 words: ['dursley', 'number', 'four', 'privet', 'drive', 'were', 'proud', 'that', 'they', 'were']
# size corpus: 44415
# size of unique words: 5601

# %%
data, count, dictionary, reverse_dictionary = build_dataset(vocabulary,vocabulary_size)
del vocabulary  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])
# Out:
# Most common words (+UNK) [['UNK', 1], ('harry', 1325), ('said', 794), ('they', 689), ('that', 686)]
# Sample data [131, 466, 241, 495, 388, 8, 1128, 4, 3, 8] ['dursley', 'number', 'four', 'privet', 'drive', 'were', 'proud', 'that', 'they', 'were']

# %%
valid_size = 16
valid_window = 100
valid_examples = np.random.choice(valid_window, valid_size, replace=False)

# %%
graph = tf.Graph()

with graph.as_default():

    train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Ops and variables pinned to the CPU because of missing GPU implementation
    with tf.device('/cpu:0'):
        embeddings = tf.Variable(tf.random_uniform([vocabulary_size, dimension], -1.0, 1.0))
        embed = tf.nn.embedding_lookup(embeddings, train_inputs)
        nce_weights = tf.Variable(tf.truncated_normal([vocabulary_size, dimension],
                                                      stddev=1.0 / np.sqrt(dimension)))
        nce_biases = tf.Variable(tf.zeros([vocabulary_size]))
        loss = tf.reduce_mean(tf.nn.nce_loss(weights=nce_weights,
                                             biases=nce_biases,
                                             labels=train_labels,
                                             inputs=embed,
                                             num_sampled=batch_size / 2,
                                             num_classes=vocabulary_size))
        optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

        # Compute the cosine similarity between minibatch examples and all embeddings.
        norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
        normalized_embeddings = embeddings / norm
        valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
        similarity = tf.matmul(valid_embeddings, normalized_embeddings, transpose_b=True)
        init = tf.global_variables_initializer()

num_steps = 200000

# %%
with tf.Session(graph=graph) as session:
    init.run()
    print('Initialized')

    average_loss = 0
    for step in range(num_steps):
        batch_inputs, batch_labels = generate_batch(batch_size, num_skips, skip_window)
        feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

        _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += loss_val

        if step % 2000 == 0:
            if step > 0:
                average_loss /= 2000
            print('Average loss at step ', step, ': ', average_loss)
            average_loss = 0

        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8  # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                log_str = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log_str = '%s %s,' % (log_str, close_word)
                print(log_str)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  112.073013306
# Nearest to said: alarming, airily, fluff, nails, toads, muffled, -the, during,
# Nearest to toward: unknown, scratchy, kiss, above, tokens, mellow, cozy, horny,
# Nearest to come: lines, wider, four-legged, weigh, steel, stumbling, nastier, gingerly,
# Nearest to something: blackpool, -the, boys, mysteriously, boogers, vain, bundles, standard,
# Nearest to where: houses, string, swelling, jabbed, woman, drained, drooling, velvet,
# Nearest to back: hurry, grimly, been, frantic, served, countryside, answer, shhh,
# Nearest to this: press, snapped, enough, fascinated, eagerly, stones, tripped, guess,
# Nearest to little: tackling, unusual, parted, maroon, knowledge, slay, urgent, eerie,
# Nearest to again: sitting, forge, bundled, sorcerer, forests, bawling, uncomfortable, wriggling,
# Nearest to never: wham, cinemas, blood-red, fields, stopped, chapter, personally, wizard,
# Nearest to right: send, presents, helicopters, merrily, occurred, ache, brandished, quicker,
# Nearest to time: ounce, streamed, dursleys, eclairs, sleepy, scuffles, proudest, destiny,
# Nearest to there: impossible, battle, passageways, flame, wildly, horrible, meant, ferociously,
# Nearest to head: puddings, charging, mightn, chose, choose, talk, staying, packages,
# Nearest to only: trifle, west, hatred, mixed, unused, road, motion, lisa,
# Nearest to potter: cheered, bearing, grief, round-faced, newspaper, eleven, quick, edged,
# Average loss at step  2000 :  27.7642425039
# Average loss at step  4000 :  6.40621238101
# Average loss at step  6000 :  4.28240263557
# Average loss at step  8000 :  3.75355161262
# Average loss at step  10000 :  3.50012582707
# Nearest to said: sharing, space, red-haired, planets, airily, outrage, joking, scruffs,
# Nearest to toward: above, unknown, cozy, loud, effort, scratchy, calmly, candy,
# Nearest to come: lines, stumbling, turkeys, steel, four-legged, weigh, remorse, coldly,
# Nearest to something: blackpool, lights, plump, -the, inferno, tuesday, born, boogers,
# Nearest to where: houses, swelling, jabbed, drained, until, shed, flooding, reeled,
# Nearest to back: hurry, alohomora, countryside, climb, seeing, served, insisted, chaser,
# Nearest to this: eagerly, breaking, blinking, overshadowed, snapped, barely, appeared, brick,
# Nearest to little: tackling, parted, unusual, eerie, cafru, maroon, urgent, howling,
# Nearest to again: bawling, forge, phone, relax, awkward, zoomed, feared, forests,
# Nearest to never: fields, queasy, stalking, separately, able, exam, personally, muggles,
# Nearest to right: helicopters, ache, least, presents, flump, destiny, mark, horny,
# Nearest to time: streamed, ounce, pictures, urgent, blasted, sheets, quidditch, rush,
# Nearest to there: twinkling, flame, wildly, hoarse, battle, chosen, accept, chat,
# Nearest to head: mightn, choose, part, charging, puddings, canary-yellow, letter, frying,
# Nearest to only: all-, sharply, trifle, knight, importantly, motion, scene, steamrollered,
# Nearest to potter: cheered, grief, quick, wheedled, round-faced, eleven, putted, learned,
# Average loss at step  12000 :  3.31866935968
# Average loss at step  14000 :  3.20755055684
# Average loss at step  16000 :  3.07531638539
# Average loss at step  18000 :  3.00974266988
# Average loss at step  20000 :  2.90336971754
# Nearest to said: sharing, joking, planets, outrage, red-haired, space, scruffs, crash,
# Nearest to toward: above, cozy, scratchy, unknown, loud, effort, mellow, calmly,
# Nearest to come: stumbling, turkeys, lines, remorse, percy, lingered, steel, weigh,
# Nearest to something: lights, blackpool, plump, inferno, born, lifted, chip, soft,
# Nearest to where: houses, swelling, jabbed, shed, self-protection, until, reeled, directions,
# Nearest to back: hurry, whispering, seeing, countryside, werewolves, served, climb, chaser,
# Nearest to this: barely, breaking, eagerly, overshadowed, umbrella, sacked, promised, prune,
# Nearest to little: cafru, tackling, parted, eerie, maroon, unusual, blast, strong,
# Nearest to again: bawling, phone, forge, boomed, zoomed, awkward, puffing, feared,
# Nearest to never: fields, queasy, muggles, separately, earned, neighbors, exam, able,
# Nearest to right: helicopters, unbelievable, duels, ache, treasure, flump, destiny, photos,
# Nearest to time: streamed, pictures, ounce, blasted, creepers, quidditch, stood, embedded,
# Nearest to there: twinkling, chosen, wildly, chat, hoarse, flame, delight, rooms,
# Nearest to head: choose, mightn, part, charging, baked, chose, frying, canary-yellow,
# Nearest to only: all-, steamrollered, sharply, scene, knight, importantly, motion, happen,
# Nearest to potter: wheedled, cheered, grief, quick, report, shore, brandished, worry,
# Average loss at step  22000 :  2.86609872246
# Average loss at step  24000 :  2.7906088109
# Average loss at step  26000 :  2.73090758914
# Average loss at step  28000 :  2.7015445199
# Average loss at step  30000 :  2.64113868135
# Nearest to said: sharing, red-haired, scruffs, crash, trials, planets, goat, annoy,
# Nearest to toward: scratchy, above, cozy, during, mellow, calmly, effort, twentieth,
# Nearest to come: turkeys, lines, remorse, stumbling, lingered, covers, july, receive,
# Nearest to something: lights, plump, inferno, born, blackpool, chuckle, lifted, chip,
# Nearest to where: swelling, houses, self-protection, reeled, directions, relieved, shed, until,
# Nearest to back: hurry, climb, whispering, seeing, served, emporium, chaser, grimly,
# Nearest to this: eagerly, barely, promised, overshadowed, breaking, umbrella, sacked, prune,
# Nearest to little: cafru, tackling, parted, eerie, blast, strong, relieved, examined,
# Nearest to again: bawling, forge, boomed, drag, among, phone, awkward, press,
# Nearest to never: fields, neighbors, earned, queasy, separately, muggles, shrilly, anxiety,
# Nearest to right: unbelievable, helicopters, duels, upright, photos, treasure, wizardry, gentleman,
# Nearest to time: streamed, pictures, hitch, exasperation, creepers, embedded, sheets, rush,
# Nearest to there: twinkling, chat, chosen, wildly, seats, yelp, passageways, accept,
# Nearest to head: choose, mightn, part, frying, canary-yellow, whispers, charging, baked,
# Nearest to only: steamrollered, all-, importantly, scene, sharply, knight, motion, shrank,
# Nearest to potter: wheedled, cheered, grief, continue, quick, report, shore, surrounded,
# Average loss at step  32000 :  2.62496272397
# Average loss at step  34000 :  2.55134889704
# Average loss at step  36000 :  2.55767373425
# Average loss at step  38000 :  2.49418361217
# Average loss at step  40000 :  2.48271363211
# Nearest to said: sharing, outrage, space, muttered, acting, wildly, red-haired, trials,
# Nearest to toward: scratchy, above, during, mellow, cozy, bricks, award, cackle,
# Nearest to come: lines, receive, turkeys, lingered, tied, july, covers, remorse,
# Nearest to something: lights, plump, inferno, chuckle, lifted, blackpool, born, angrier,
# Nearest to where: swelling, self-protection, directions, relieved, fanatic, perfect, houses, reeled,
# Nearest to back: hurry, seeing, emporium, whispering, werewolves, tentacles, served, starts,
# Nearest to this: barely, prune, overshadowed, eagerly, promised, sacked, safe, breaking,
# Nearest to little: cafru, tackling, parted, blast, eerie, examined, relieved, strong,
# Nearest to again: bawling, forge, boomed, drag, among, phone, nothing, zoomed,
# Nearest to never: fields, earned, neighbors, queasy, separately, anxiety, shrilly, nerves,
# Nearest to right: unbelievable, duels, helicopters, upright, youngsters, photos, gentleman, treasure,
# Nearest to time: streamed, pictures, hitch, viridian, rush, exasperation, embedded, shortcut,
# Nearest to there: twinkling, wildly, chat, defrosting, chosen, pebbles, ordered, know,
# Nearest to head: part, choose, whispers, baked, chose, clue, patrolled, mightn,
# Nearest to only: all-, steamrollered, knight, importantly, scene, scuffles, shrank, sharply,
# Nearest to potter: wheedled, grief, continue, worry, cheered, shore, report, quick,
# Average loss at step  42000 :  2.45854816976
# Average loss at step  44000 :  2.4256308434
# Average loss at step  46000 :  2.42095309436
# Average loss at step  48000 :  2.37714342269
# Average loss at step  50000 :  2.3889114204
# Nearest to said: sharing, muttered, liquid, red-haired, outrage, acting, goat, wildly,
# Nearest to toward: scratchy, during, cackle, cozy, flung, paracelsus, bricks, mellow,
# Nearest to come: receive, tied, turkeys, train, july, covers, lingered, remorse,
# Nearest to something: lights, inferno, plump, chuckle, lifted, blackpool, soft, angrier,
# Nearest to where: swelling, fanatic, perfect, relieved, directions, self-protection, beasts, rubbed,
# Nearest to back: hurry, served, emporium, dusk, sunlight, tentacles, seeing, crash,
# Nearest to this: safe, prune, barely, overshadowed, promised, eagerly, dittany, umbrella,
# Nearest to little: tackling, cafru, parted, examined, blast, relieved, aaah, tiptoe,
# Nearest to again: drag, bawling, boomed, forge, nothing, among, forests, choice,
# Nearest to never: fields, earned, neighbors, queasy, anxiety, skipped, separately, spose,
# Nearest to right: unbelievable, upright, helicopters, duels, photos, tear-streaked, gentleman, treasure,
# Nearest to time: hitch, streamed, pictures, exasperation, creepers, rush, duddydums, viridian,
# Nearest to there: twinkling, wildly, pebbles, steered, rooms, defrosting, chat, ordered,
# Nearest to head: part, patrolled, baked, gasps, choose, dreadlocks, whispers, canary-yellow,
# Nearest to only: all-, steamrollered, shrank, importantly, scene, struck, answer, knight,
# Nearest to potter: wheedled, worry, continue, shore, report, grief, cheered, hello,
# Average loss at step  52000 :  2.34221208477
# Average loss at step  54000 :  2.36303549343
# Average loss at step  56000 :  2.32081889188
# Average loss at step  58000 :  2.32094636327
# Average loss at step  60000 :  2.30534393463
# Nearest to said: sharing, acting, liquid, gulpin, outrage, muttered, wildly, edging,
# Nearest to toward: scratchy, during, cackle, flung, steps, paracelsus, cozy, shortcut,
# Nearest to come: receive, remorse, turkeys, tied, -lessons, definitely, here, train,
# Nearest to something: lights, plump, lifted, inferno, chuckle, blackpool, warmer, sprinting,
# Nearest to where: perfect, glistening, swelling, relieved, directions, fanatic, rubbed, self-protection,
# Nearest to back: hurry, grimly, served, acting, emporium, seeing, tentacles, climb,
# Nearest to this: promised, prune, chained, overshadowed, safe, eagerly, umbrella, dittany,
# Nearest to little: tackling, cafru, parted, blast, tiptoe, examined, eclairs, relieved,
# Nearest to again: drag, nothing, bawling, boomed, forge, among, magnificent, choice,
# Nearest to never: fields, neighbors, queasy, nightfall, skipped, anxiety, earned, separately,
# Nearest to right: unbelievable, photos, helicopters, duels, upright, gentleman, youngsters, destiny,
# Nearest to time: hitch, duddydums, exasperation, creepers, pictures, viridian, streamed, shortcut,
# Nearest to there: twinkling, wildly, defrosting, pebbles, stoked, chat, panting, chosen,
# Nearest to head: part, patrolled, clue, canary-yellow, shrinking, whispers, helped, wandered,
# Nearest to only: all-, steamrollered, struck, importantly, answer, shrank, scene, bowling,
# Nearest to potter: wheedled, continue, worry, report, hello, shore, quick, surrounded,
# Average loss at step  62000 :  2.28782142773
# Average loss at step  64000 :  2.31734087074
# Average loss at step  66000 :  2.26527450377
# Average loss at step  68000 :  2.29016708371
# Average loss at step  70000 :  2.24461121142
# Nearest to said: sharing, outrage, muttered, airily, acting, drooled, panicking, crash,
# Nearest to toward: scratchy, cackle, during, flung, steps, paracelsus, shallows, looks,
# Nearest to come: receive, tied, -lessons, definitely, explaining, turkeys, child, remorse,
# Nearest to something: lights, lifted, plump, relatives, sweaters, chuckle, inferno, warmer,
# Nearest to where: relieved, perfect, fanatic, self-protection, glistening, swelling, rubbed, directions,
# Nearest to back: hurry, that, emporium, served, climb, acting, gloom, dusk,
# Nearest to this: safe, promised, prune, umbrella, dittany, sleeps, fascinated, hags,
# Nearest to little: tackling, cafru, parted, blast, tiptoe, examined, eerie, eclairs,
# Nearest to again: drag, nothing, boomed, forge, bawling, among, awkward, choice,
# Nearest to never: fields, neighbors, anxiety, nerves, skipped, queasy, nightfall, separately,
# Nearest to right: unbelievable, upright, helicopters, photos, gentleman, youngsters, zombie, treasure,
# Nearest to time: hitch, shortcut, exasperation, rush, all-, grandmother, creepers, buck,
# Nearest to there: twinkling, wildly, pebbles, stoked, defrosting, ordered, hoarse, stalagmite,
# Nearest to head: part, shrinking, patrolled, canary-yellow, positively, whispers, clue, helped,
# Nearest to only: all-, steamrollered, struck, shrank, answer, scene, importantly, bowling,
# Nearest to potter: wheedled, worry, continue, hello, report, shore, escape, surrounded,
# Average loss at step  72000 :  2.27992995173
# Average loss at step  74000 :  2.24479111293
# Average loss at step  76000 :  2.25221287835
# Average loss at step  78000 :  2.24937963045
# Average loss at step  80000 :  2.23360794231
# Nearest to said: sharing, acting, wildly, panicking, red-haired, liquid, goat, outrage,
# Nearest to toward: scratchy, cackle, during, flung, steps, paracelsus, twist, petrificus,
# Nearest to come: receive, -lessons, tied, child, turkeys, rumbling, explaining, laws,
# Nearest to something: lights, lifted, plump, relatives, warmer, sweaters, family, chuckle,
# Nearest to where: glistening, relieved, perfect, fanatic, directions, self-protection, rubbed, fuming,
# Nearest to back: hurry, dusk, climb, tentacles, cooked, acting, emporium, werewolves,
# Nearest to this: prune, safe, dittany, promised, eagerly, fascinated, chained, barely,
# Nearest to little: tackling, cafru, blast, parted, examined, tiptoe, horrified, relieved,
# Nearest to again: drag, bawling, nothing, boomed, forge, choice, among, phone,
# Nearest to never: fields, anxiety, queasy, nerves, neighbors, skipped, spose, earned,
# Nearest to right: unbelievable, gentleman, upright, swig, helicopters, zombie, duels, photos,
# Nearest to time: hitch, exasperation, all-, favor, grandmother, prewetts, shortcut, later,
# Nearest to there: twinkling, wildly, stoked, pebbles, panting, chat, yelp, defrosting,
# Nearest to head: part, canary-yellow, whispers, patrolled, shrinking, helped, positively, extraordinary,
# Nearest to only: all-, steamrollered, struck, shrank, scene, answer, pitch, revolting,
# Nearest to potter: wheedled, continue, worry, hello, report, bossy, surrounded, used,
# Average loss at step  82000 :  2.25080930811
# Average loss at step  84000 :  2.21012974453
# Average loss at step  86000 :  2.24895939255
# Average loss at step  88000 :  2.2087520445
# Average loss at step  90000 :  2.22513618539
# Nearest to said: liquid, sharing, outrage, wildly, muttered, muffled, acting, bellowed,
# Nearest to toward: scratchy, cackle, during, flung, paracelsus, petrificus, unused, shallows,
# Nearest to come: receive, tied, remorse, -lessons, child, explaining, july, turkeys,
# Nearest to something: lights, plump, lifted, relatives, wished, inferno, chuckle, sleepiness,
# Nearest to where: fanatic, glistening, relieved, directions, self-protection, perfect, fuming, beasts,
# Nearest to back: hurry, dusk, served, climb, emporium, holes, grimly, prophet,
# Nearest to this: safe, chained, should, dittany, overshadowed, barely, sacked, promised,
# Nearest to little: tackling, cafru, blast, tiptoe, parted, examined, horrified, eclairs,
# Nearest to again: drag, nothing, bawling, boomed, forge, choice, among, earths,
# Nearest to never: neighbors, fields, skipped, queasy, spose, allowed, anxiety, nerves,
# Nearest to right: unbelievable, upright, duels, zombie, photos, gentleman, youngsters, swig,
# Nearest to time: hitch, all-, exasperation, favor, shortcut, foreheads, grandmother, personally,
# Nearest to there: wildly, twinkling, pebbles, hoarse, passageways, rooms, yelp, ferociously,
# Nearest to head: shrinking, whispers, part, canary-yellow, patrolled, chose, wandered, charging,
# Nearest to only: all-, struck, steamrollered, shrank, scene, answer, bowling, revolting,
# Nearest to potter: wheedled, continue, hello, worry, bossy, report, clinging, liar,
# Average loss at step  92000 :  2.20925688782
# Average loss at step  94000 :  2.2153627159
# Average loss at step  96000 :  2.210747374
# Average loss at step  98000 :  2.19432351688
# Average loss at step  100000 :  2.21877969706
# Nearest to said: muttered, sharing, liquid, acting, funny-looking, scruffs, wildly, goat,
# Nearest to toward: scratchy, during, cackle, flung, steps, pumpkins, unused, strapping,
# Nearest to come: receive, tied, -lessons, child, here, remorse, turkeys, explaining,
# Nearest to something: lights, plump, lifted, inferno, such, warmer, relatives, chuckle,
# Nearest to where: glistening, fanatic, directions, relieved, perfect, fuming, forbid, self-protection,
# Nearest to back: hurry, dusk, chose, served, crept, climb, emporium, cooked,
# Nearest to this: hags, prune, safe, chained, promised, should, umbrella, overshadowed,
# Nearest to little: tackling, blast, cafru, demands, parted, relieved, horrified, tiptoe,
# Nearest to again: drag, nothing, bawling, boomed, forge, among, earths, choice,
# Nearest to never: fields, skipped, neighbors, queasy, scurried, spose, anxiety, nerves,
# Nearest to right: unbelievable, zombie, photos, upright, swig, gentleman, youngsters, helicopters,
# Nearest to time: hitch, all-, grandmother, favor, prewetts, shortcut, viridian, duddydums,
# Nearest to there: pebbles, twinkling, wildly, ferociously, badly, stoked, yelp, bills,
# Nearest to head: patrolled, whispers, chose, wandered, part, helped, might, shrinking,
# Nearest to only: struck, all-, shrank, scene, steamrollered, answer, bowling, revolting,
# Nearest to potter: wheedled, continue, hello, worry, clinging, report, bossy, howard,
# Average loss at step  102000 :  2.18051435158
# Average loss at step  104000 :  2.21609247495
# Average loss at step  106000 :  2.18951174439
# Average loss at step  108000 :  2.19429281624
# Average loss at step  110000 :  2.1843209455
# Nearest to said: sharing, liquid, goat, muttered, gulpin, tentacles, wildly, switching,
# Nearest to toward: cackle, scratchy, steps, during, pumpkins, flung, unused, petrificus,
# Nearest to come: -lessons, tied, receive, child, here, insisted, carelessly, explaining,
# Nearest to something: lights, plump, relatives, such, sweaters, lifted, brooms, warmer,
# Nearest to where: glistening, fanatic, self-protection, relieved, fuming, rubbed, directions, flies,
# Nearest to back: hurry, dusk, emporium, climb, served, linen, holes, bendy,
# Nearest to this: prune, dittany, safe, refusing, lamps, barely, should, hags,
# Nearest to little: tackling, cafru, blast, tiptoe, examined, horrified, glinting, eerie,
# Nearest to again: drag, nothing, bawling, among, earths, boomed, forge, choice,
# Nearest to never: fields, queasy, neighbors, skipped, anxiety, spose, nerves, scurried,
# Nearest to right: unbelievable, upright, zombie, punished, photos, swig, gentleman, youngsters,
# Nearest to time: hitch, all-, exasperation, grandmother, shortcut, later, children, prewetts,
# Nearest to there: pebbles, twinkling, wildly, stoked, chat, chosen, hoarse, badly,
# Nearest to head: canary-yellow, patrolled, shrinking, helped, chose, wandered, whispers, panting,
# Nearest to only: struck, all-, answer, steamrollered, scene, shrank, revolting, bowling,
# Nearest to potter: wheedled, continue, worry, hello, report, bossy, clinging, surrounded,
# Average loss at step  112000 :  2.17644838411
# Average loss at step  114000 :  2.20898487517
# Average loss at step  116000 :  2.17564185572
# Average loss at step  118000 :  2.20160087684
# Average loss at step  120000 :  2.15409516639
# Nearest to said: sharing, panicking, funny-looking, fortune-telling, muttered, liquid, frowning, red-haired,
# Nearest to toward: scratchy, cackle, steps, during, flung, unused, pumpkins, shallows,
# Nearest to come: receive, tied, child, explaining, -lessons, carelessly, remorse, turkeys,
# Nearest to something: lights, plump, such, cloak, relatives, brooms, wished, warmer,
# Nearest to where: fanatic, glistening, fuming, rubbed, relieved, self-protection, flies, cover-,
# Nearest to back: hurry, climb, served, linen, acting, crept, spoil, trimble,
# Nearest to this: prune, safe, barely, hags, promised, chained, sleeps, should,
# Nearest to little: tackling, cafru, horrified, blast, glinting, eerie, tiptoe, purple-faced,
# Nearest to again: drag, nothing, bawling, forge, boomed, choice, earths, among,
# Nearest to never: fields, nightfall, spose, neighbors, skipped, queasy, anxiety, changing,
# Nearest to right: unbelievable, upright, swig, photos, youngsters, zombie, gentleman, punished,
# Nearest to time: hitch, grandmother, exasperation, all-, prewetts, buck, later, favor,
# Nearest to there: twinkling, panting, wildly, stalagmite, chat, pebbles, yelp, straightening,
# Nearest to head: canary-yellow, whispers, chose, helped, murmured, charging, patrolled, dishes,
# Nearest to only: struck, all-, answer, steamrollered, shrank, scene, bowling, difference,
# Nearest to potter: wheedled, continue, hello, worry, report, surrounded, bossy, used,
# Average loss at step  122000 :  2.19990156984
# Average loss at step  124000 :  2.1612814464
# Average loss at step  126000 :  2.17471948245
# Average loss at step  128000 :  2.17935345376
# Average loss at step  130000 :  2.16407152987
# Nearest to said: sharing, red-haired, airily, panicking, wildly, resolution, scruffs, liquid,
# Nearest to toward: scratchy, cackle, shallows, flung, steps, during, pumpkins, unused,
# Nearest to come: explaining, child, -lessons, tied, receive, carelessly, laws, ronald,
# Nearest to something: lights, plump, such, warmer, lifted, relatives, wished, thrown,
# Nearest to where: fanatic, self-protection, relieved, perfect, flies, glistening, beasts, rubbed,
# Nearest to back: served, tentacles, dusk, cooked, emporium, hurry, crept, wasted,
# Nearest to this: prune, hags, alas, safe, barely, promised, overshadowed, fascinated,
# Nearest to little: tackling, cafru, horrified, blast, glinting, tiptoe, demands, wave,
# Nearest to again: drag, bawling, nothing, choice, boomed, forge, earths, jumping,
# Nearest to never: fields, skipped, neighbors, nerves, spose, queasy, allowed, anxiety,
# Nearest to right: unbelievable, upright, swig, impressively, youngsters, zombie, mothers, punished,
# Nearest to time: hitch, grandmother, shortcut, later, all-, prewetts, bodyguards, exasperation,
# Nearest to there: twinkling, pebbles, panting, chat, wildly, yelp, stalagmite, ferociously,
# Nearest to head: chose, whispers, canary-yellow, murmured, wandered, charging, bustled, helped,
# Nearest to only: struck, all-, scene, answer, shrank, steamrollered, revolting, spose,
# Nearest to potter: wheedled, continue, hello, worry, surrounded, bossy, clinging, survive,
# Average loss at step  132000 :  2.19473209196
# Average loss at step  134000 :  2.16027653241
# Average loss at step  136000 :  2.18457263421
# Average loss at step  138000 :  2.14661312774
# Average loss at step  140000 :  2.18957692352
# Nearest to said: wildly, sharing, bellowed, outrage, liquid, acting, funny-looking, scruffs,
# Nearest to toward: scratchy, cackle, pumpkins, flung, during, steps, shallows, unused,
# Nearest to come: child, -lessons, tied, laws, explaining, receive, here, collapsible,
# Nearest to something: lights, wished, plump, such, relatives, warmer, inferno, unpopular,
# Nearest to where: fanatic, glistening, fuming, packed, self-protection, flies, forbid, directions,
# Nearest to back: dusk, served, climb, hurry, linen, cooked, emporium, shakily,
# Nearest to this: prune, alas, hags, safe, sleeps, barely, overshadowed, harp,
# Nearest to little: tackling, horrified, demands, blast, wailed, cafru, eerie, tiptoe,
# Nearest to again: drag, bawling, forge, nothing, earths, boomed, choice, jumping,
# Nearest to never: fields, neighbors, skipped, queasy, allowed, wriggles, anxiety, spose,
# Nearest to right: unbelievable, upright, punished, rammed, swig, gentleman, photos, zombie,
# Nearest to time: all-, grandmother, bodyguards, hitch, exasperation, shortcut, children, personally,
# Nearest to there: pebbles, chat, twinkling, wildly, yelp, badly, panting, ordered,
# Nearest to head: murmured, whispers, chose, helped, canary-yellow, dishes, privately, random,
# Nearest to only: struck, all-, answer, bowling, scene, steamrollered, shrank, revolting,
# Nearest to potter: wheedled, continue, hello, worry, surrounded, survive, clinging, bossy,
# Average loss at step  142000 :  2.15443874523
# Average loss at step  144000 :  2.17044816932
# Average loss at step  146000 :  2.17153517389
# Average loss at step  148000 :  2.14984647682
# Average loss at step  150000 :  2.18529047407
# Nearest to said: liquid, sharing, acting, muttered, twenty-nine, fortunately, bellowed, funny-looking,
# Nearest to toward: pumpkins, scratchy, cackle, during, steps, unused, flung, strapping,
# Nearest to come: -lessons, child, receive, tied, laws, explaining, insisted, here,
# Nearest to something: lights, plump, such, things, wished, warmer, might, lifted,
# Nearest to where: fanatic, fuming, directions, glistening, perfect, relieved, forbid, flies,
# Nearest to back: served, dusk, hurry, climb, wasted, triumphs, linen, emporium,
# Nearest to this: prune, sleeps, promised, overshadowed, chained, hags, harp, safe,
# Nearest to little: tackling, horrified, glinting, tiptoe, cafru, blast, demands, wave,
# Nearest to again: drag, nothing, earths, bawling, forge, choice, boomed, sorry,
# Nearest to never: neighbors, skipped, fields, scurried, anxiety, wriggles, nerves, queasy,
# Nearest to right: unbelievable, upright, photos, rammed, swig, punished, zombie, impressively,
# Nearest to time: hitch, grandmother, prewetts, all-, shortcut, buck, children, foreheads,
# Nearest to there: pebbles, wildly, twinkling, ferociously, badly, stoked, admirable, penalty,
# Nearest to head: helped, whispers, chose, canary-yellow, murmured, charging, meters, occurred,
# Nearest to only: struck, answer, all-, shrank, revolting, scene, bowling, banks,
# Nearest to potter: wheedled, continue, worry, hello, liar, clinging, survive, surrounded,
# Average loss at step  152000 :  2.14512104052
# Average loss at step  154000 :  2.17835669488
# Average loss at step  156000 :  2.14414642468
# Average loss at step  158000 :  2.16853018728
# Average loss at step  160000 :  2.15105929178
# Nearest to said: bellowed, gulpin, wildly, sharing, fortune-telling, acting, tenpin, panicking,
# Nearest to toward: scratchy, cackle, flung, pumpkins, during, nodded, steps, unused,
# Nearest to come: -lessons, child, insisted, tied, laws, carelessly, here, receive,
# Nearest to something: lights, such, plump, warmer, wished, relatives, struck, lifted,
# Nearest to where: fuming, fanatic, glistening, flies, directions, forbid, splashes, rubbed,
# Nearest to back: cooked, served, holes, acting, aaaargh, prophet, dusk, climb,
# Nearest to this: prune, hags, overshadowed, lamps, chained, should, promised, dittany,
# Nearest to little: tackling, horrified, blast, cafru, glinting, tiptoe, demands, wailed,
# Nearest to again: drag, bawling, nothing, earths, choice, boomed, forge, among,
# Nearest to never: neighbors, fields, nightfall, nerves, skipped, spose, anxiety, changing,
# Nearest to right: unbelievable, upright, rammed, photos, punished, swig, zombie, impressively,
# Nearest to time: hitch, grandmother, children, exasperation, viridian, shortcut, all-, buck,
# Nearest to there: twinkling, pebbles, stoked, wildly, admirable, stalagmite, ferociously, badly,
# Nearest to head: murmured, canary-yellow, chose, whispers, random, wandered, bustled, privately,
# Nearest to only: struck, all-, answer, steamrollered, revolting, scene, bowling, shakeem,
# Nearest to potter: wheedled, continue, worry, hello, bossy, surrounded, liar, used,
# Average loss at step  162000 :  2.15716126814
# Average loss at step  164000 :  2.17223870878
# Average loss at step  166000 :  2.14459475537
# Average loss at step  168000 :  2.16901241454
# Average loss at step  170000 :  2.13046439615
# Nearest to said: sharing, tenpin, funny-looking, muffled, bellowed, boomed, goat, deserved,
# Nearest to toward: cackle, pumpkins, scratchy, steps, flung, during, unused, nodded,
# Nearest to come: explaining, child, -lessons, tied, receive, carelessly, here, laws,
# Nearest to something: lights, plump, such, warmer, relatives, mingled, angrier, abnormal,
# Nearest to where: flies, fanatic, fuming, glistening, rubbed, hams, relieved, perfect,
# Nearest to back: dusk, flump, relieved, cooked, holes, whispering, emporium, crept,
# Nearest to this: prune, hags, harp, drawback, should, promised, alas, sleeps,
# Nearest to little: tackling, horrified, cafru, demands, blast, glinting, tiptoe, eerie,
# Nearest to again: drag, earths, bawling, nothing, forge, boomed, choice, sorry,
# Nearest to never: nightfall, spose, anxiety, scurried, maybe, fields, skipped, changing,
# Nearest to right: unbelievable, upright, swig, photos, rammed, youngsters, zombie, duels,
# Nearest to time: grandmother, hitch, children, exasperation, shortcut, all-, bodyguards, favor,
# Nearest to there: twinkling, wildly, stalagmite, admirable, ferociously, panting, straightening, badly,
# Nearest to head: murmured, chose, whispers, canary-yellow, helped, random, dishes, occurred,
# Nearest to only: struck, all-, steamrollered, answer, swore, scene, revolting, bowling,
# Nearest to potter: wheedled, continue, worry, hello, surrounded, liar, bossy, pressure,
# Average loss at step  172000 :  2.16852360383
# Average loss at step  174000 :  2.13544636986
# Average loss at step  176000 :  2.15422674608
# Average loss at step  178000 :  2.14446170672
# Average loss at step  180000 :  2.14222294492
# Nearest to said: sharing, boomed, liquid, panicking, frowning, scruffs, funny-looking, coulda,
# Nearest to toward: pumpkins, scratchy, flung, cackle, during, steps, nodded, unused,
# Nearest to come: -lessons, tied, child, receive, explaining, laws, carelessly, insisted,
# Nearest to something: lights, plump, abnormal, warmer, thrown, such, wished, relatives,
# Nearest to where: fanatic, glistening, flies, self-protection, perfect, directions, stonewall, hams,
# Nearest to back: dusk, served, said, picture, wasted, emporium, holes, shakily,
# Nearest to this: prune, drawback, harp, fidgeted, hags, dittany, self-stirring, promised,
# Nearest to little: tackling, horrified, glinting, blast, demands, cafru, aaah, wave,
# Nearest to again: drag, bawling, earths, choice, nothing, forge, meal, boomed,
# Nearest to never: neighbors, anxiety, scurried, nightfall, nerves, queasy, spose, fields,
# Nearest to right: unbelievable, upright, rammed, photos, impressively, swam, swig, youngsters,
# Nearest to time: grandmother, hitch, exasperation, all-, favor, children, shortcut, foreheads,
# Nearest to there: pebbles, chat, panting, admirable, badly, straightening, stoked, ferociously,
# Nearest to head: murmured, baked, random, whispers, chose, shrinking, canary-yellow, wandered,
# Nearest to only: struck, all-, answer, shrank, steamrollered, scene, ollivanders, bowling,
# Nearest to potter: wheedled, continue, hello, unicorns, surrounded, worry, survive, bossy,
# Average loss at step  182000 :  2.16044315982
# Average loss at step  184000 :  2.13350054723
# Average loss at step  186000 :  2.16398623773
# Average loss at step  188000 :  2.12966785076
# Average loss at step  190000 :  2.16767211747
# Nearest to said: sharing, funny-looking, howard, wildly, explaining, stumped, acting, red-haired,
# Nearest to toward: scratchy, pumpkins, cackle, flung, during, steps, nodded, shallows,
# Nearest to come: -lessons, child, explaining, tied, receive, laws, insisted, here,
# Nearest to something: lights, plump, warmer, such, wished, cloak, relatives, struck,
# Nearest to where: fanatic, flies, fuming, packed, forbid, perfect, glistening, sheep,
# Nearest to back: served, wasted, emporium, dusk, hall, holes, flump, rested,
# Nearest to this: prune, overshadowed, chained, drawback, alas, occurred, harp, promised,
# Nearest to little: tackling, horrified, blast, tiptoe, glinting, demands, wailed, eerie,
# Nearest to again: drag, earths, bawling, nothing, meal, choice, boomed, forge,
# Nearest to never: queasy, scurried, neighbors, skipped, nerves, nightfall, anxiety, fields,
# Nearest to right: unbelievable, upright, rammed, swig, photos, whap, impressively, treasure,
# Nearest to time: children, grandmother, taught, hitch, exasperation, shortcut, viridian, prewetts,
# Nearest to there: pebbles, twinkling, wildly, chat, admirable, badly, hoarse, stalagmite,
# Nearest to head: murmured, chose, whispers, gateway, dishes, faltered, random, canary-yellow,
# Nearest to only: struck, all-, abnormal, shakeem, swore, banks, steamrollered, answer,
# Nearest to potter: wheedled, continue, surrounded, worry, hello, liar, clinging, survive,
# Average loss at step  192000 :  2.12769780021
# Average loss at step  194000 :  2.14357504013
# Average loss at step  196000 :  2.1489636057
# Average loss at step  198000 :  2.13112086797

# %%
with open('sorcererstone-list.p', 'wb') as fopen:
    pickle.dump(list(reverse_dictionary.values()), fopen)

# %%
with open('sorcererstone-vector.p', 'wb') as fopen:
    pickle.dump(final_embeddings, fopen)
