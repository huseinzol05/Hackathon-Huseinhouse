# %%
import re
import tensorflow as tf
import numpy as np
import time
import os
import collections
import random
import nltk
import time
import pickle

# %%
def clearstring(string):
    string = re.sub('[^A-Za-z\- ]+', '', string)
    string = string.split(' ')
    string = filter(None, string)
    string = [y.strip() for y in string]
    return [y.lower() for y in string if len(y) > 3 and y.find('nbsp') < 0]

def build_dataset(words, n_words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(n_words - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        index = dictionary.get(word, 0)
        if index == 0:  # dictionary['UNK']
            unk_count += 1
        data.append(index)
    count[0][1] = unk_count
    reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reversed_dictionary

data_index = 0

# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    global data
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1  # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    if data_index + span > len(data):
        data_index = 0
    buffer.extend(data[data_index:data_index + span])
    data_index += span
    for i in range(batch_size // num_skips):
        context_words = [w for w in range(span) if w != skip_window]
        words_to_use = random.sample(context_words, num_skips)
        for j, context_word in enumerate(words_to_use):
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[context_word]
        if data_index == len(data):
            for word in data[:span]:
                buffer.append(word)
            data_index = span
        else:
            buffer.append(data[data_index])
            data_index += 1
    # Backtrack a little bit to avoid skipping words in the end of a batch
    data_index = (data_index + len(data) - span) % len(data)
    return batch, labels

# %%
with open('books/The-Hunger-Games.txt', 'r',encoding = "ISO-8859-1") as fopen:
    vocabulary = clearstring(' '.join(nltk.word_tokenize(fopen.read())))
print('example 10 words:',vocabulary[:10])
print('size corpus:',len(vocabulary))
vocabulary_size = len(list(set(vocabulary)))
print('size of unique words:',vocabulary_size)
dimension = 128
skip_window = 1
num_skips = 2
batch_size = 64
location = os.getcwd()
# Out:
# example 10 words: ['hunger', 'games', 'hunger', 'games', 'suzanne', 'collins', 'part', 'tributes', 'when', 'wake']
# size corpus: 54070
# size of unique words: 7390

# %%
data, count, dictionary, reverse_dictionary = build_dataset(vocabulary,vocabulary_size)
del vocabulary  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])
# Out:
# Most common words (+UNK) [['UNK', 1], ('that', 831), ('with', 634), ('have', 596), ('from', 526)]
# Sample data [241, 75, 241, 75, 5203, 5579, 238, 56, 9, 602] ['hunger', 'games', 'hunger', 'games', 'suzanne', 'collins', 'part', 'tributes', 'when', 'wake']

# %%
valid_size = 16
valid_window = 100
valid_examples = np.random.choice(valid_window, valid_size, replace=False)

# %%
graph = tf.Graph()

with graph.as_default():

    train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Ops and variables pinned to the CPU because of missing GPU implementation
    with tf.device('/cpu:0'):
        embeddings = tf.Variable(tf.random_uniform([vocabulary_size, dimension], -1.0, 1.0))
        embed = tf.nn.embedding_lookup(embeddings, train_inputs)
        nce_weights = tf.Variable(tf.truncated_normal([vocabulary_size, dimension],
                                                      stddev=1.0 / np.sqrt(dimension)))
        nce_biases = tf.Variable(tf.zeros([vocabulary_size]))
        loss = tf.reduce_mean(tf.nn.nce_loss(weights=nce_weights,
                                             biases=nce_biases,
                                             labels=train_labels,
                                             inputs=embed,
                                             num_sampled=batch_size / 2,
                                             num_classes=vocabulary_size))
        optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

        # Compute the cosine similarity between minibatch examples and all embeddings.
        norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
        normalized_embeddings = embeddings / norm
        valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
        similarity = tf.matmul(valid_embeddings, normalized_embeddings, transpose_b=True)
        init = tf.global_variables_initializer()

num_steps = 200000

# %%
with tf.Session(graph=graph) as session:
    init.run()
    print('Initialized')

    average_loss = 0
    for step in range(num_steps):
        batch_inputs, batch_labels = generate_batch(batch_size, num_skips, skip_window)
        feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

        _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += loss_val

        if step % 2000 == 0:
            if step > 0:
                average_loss /= 2000
            print('Average loss at step ', step, ': ', average_loss)
            average_loss = 0

        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8  # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                log_str = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log_str = '%s %s,' % (log_str, close_word)
                print(log_str)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  120.172103882
# Nearest to UNK: nightmare, carve, desperation, strategy, weeks, buried, cloak, vines,
# Nearest to never: disaster, explanations, undetectable, deadliest-looking, skys, claws, canister, forward,
# Nearest to more: frogs, cleaned, rebounds, forty, crosses, shrunk, peacekeeper, fighter,
# Nearest to cato: pitied, aloud, nightfall, circumstances, breached, suspect, convulses, catching,
# Nearest to only: boxing, labs, heavily, fate, reserved, flops, maintain, crusts,
# Nearest to dont: interaction, reach, wept, slimy, insult, good-natured, flounder, babble,
# Nearest to back: clenched, rabid, president, dangerous, insufficient, mean, forest, entitled,
# Nearest to take: blinding, kick, daily, ahead, drenched, badly, shaped, away,
# Nearest to moment: amount, grain, gulp, retire, slashes, massage, ration, notices,
# Nearest to capitol: naked, reenactments, tumble, affection, peering, dragging, hazel, twitch,
# Nearest to like: oblivious, hobbled, actions, motivated, hallucination, crippled, boots, fence,
# Nearest to think: perfection, upbeat, latter, forth, pre-arena, path, doomed, fond,
# Nearest to people: suffocate, situation, shaking, molded, poke, ability, sandals, unraveled,
# Nearest to where: apples, hideout, grill, soot, uninjured, jets, grandkids, yearling,
# Nearest to they: scared, resolving, shouts, unfortunately, mangled, self-conscious, enlist, hiking,
# Nearest to over: corn, asked, emptiness, healer, safest, snagging, spied, five-year-old,
# Average loss at step  2000 :  35.2708687384
# Average loss at step  4000 :  9.1301850816
# Average loss at step  6000 :  5.20763598537
# Average loss at step  8000 :  4.14188712823
# Average loss at step  10000 :  3.77549209058
# Nearest to UNK: nightmare, vines, carve, weeks, strategy, desperation, stuck, buried,
# Nearest to never: palms, explanations, disaster, mush, contrived, believes, undetectable, claws,
# Nearest to more: yard, frogs, strolling, experiment, fighter, uncomplaining, peacekeeper, crawled,
# Nearest to cato: halfway, groggy, pitied, nightfall, aloud, walks, activate, half-dozen,
# Nearest to only: maintain, boxing, addressed, reserved, labs, yelling, fluffy, contestants,
# Nearest to dont: wept, good-natured, adding, babble, glue, shoes, looking, settings,
# Nearest to back: party, forest, effective, pointing, underarms, edible, quicker, downhill,
# Nearest to take: daily, kick, drenched, expectations, blinding, prop, stone, ahead,
# Nearest to moment: grain, amount, gulp, retire, massage, ration, slashes, notices,
# Nearest to capitol: naked, problems, reenactments, tumble, dragging, bloom, tearing, since,
# Nearest to like: dictate, boots, oblivious, yanks, punctures, rate, using, actions,
# Nearest to think: forth, pre-arena, doomed, mean, despondency, filling, perfection, shower,
# Nearest to people: suffocate, molded, situation, reduce, ability, news, grandeur, shaking,
# Nearest to where: grill, hideout, cloths, uninjured, survive, wept, soot, lock,
# Nearest to they: scared, shouts, resolving, foxface, shoulders, urges, unfortunately, leave,
# Nearest to over: corn, comparing, spied, five-year-old, properly, hauled, safest, radius,
# Average loss at step  12000 :  3.55958071363
# Average loss at step  14000 :  3.38015200126
# Average loss at step  16000 :  3.25408713138
# Average loss at step  18000 :  3.14626381016
# Average loss at step  20000 :  3.07658533978
# Nearest to UNK: nightmare, vines, carve, desperation, weeks, rabid, subdued, bottom,
# Nearest to never: couldve, explanations, disaster, believes, ignored, contrived, mush, undetectable,
# Nearest to more: frogs, yard, strolling, fighter, mumbles, pokeweed, wears, uncomplaining,
# Nearest to cato: halfway, groggy, personal, west, nightfall, pitied, activate, walks,
# Nearest to only: maintain, boxing, addressed, reserved, labs, condenses, many, contestants,
# Nearest to dont: good-natured, wept, looking, adding, babble, glue, tomorrows, settings,
# Nearest to back: party, effective, underarms, numbness, nice, indifferent, quicker, maces,
# Nearest to take: drenched, daily, prop, expectations, securing, interested, kick, blinding,
# Nearest to moment: grain, gulp, amount, ration, retire, massage, destinations, slashes,
# Nearest to capitol: problems, naked, awkward, conjure, reenactments, tearing, frightened, tumble,
# Nearest to like: dictate, yanks, oblivious, rate, punctures, using, hyperventilating, boots,
# Nearest to think: forth, lighten, pre-arena, luckily, doomed, traitor, temper, mean,
# Nearest to people: suffocate, molded, stinging, reduce, roots, grandeur, situation, bothering,
# Nearest to where: hideout, grill, cloths, uninjured, wept, because, survive, drop-off,
# Nearest to they: resolving, shouts, urges, foxface, shorts, leave, scared, jabber,
# Nearest to over: comparing, corn, hauled, radius, properly, healer, safest, festivity,
# Average loss at step  22000 :  2.99630222493
# Average loss at step  24000 :  2.90786599082
# Average loss at step  26000 :  2.85720770043
# Average loss at step  28000 :  2.8067994808
# Average loss at step  30000 :  2.75474181193
# Nearest to UNK: nightmare, carve, rabid, vines, bottom, buried, liking, subdued,
# Nearest to never: couldve, disaster, ignored, explanations, believes, showers, remake, mush,
# Nearest to more: frogs, strolling, fighter, yard, mumbles, uncomplaining, pokeweed, wears,
# Nearest to cato: west, groggy, halfway, personal, razor-sharp, half-dozen, activate, pitied,
# Nearest to only: boxing, maintain, pursue, contestants, condenses, labs, addressed, betting,
# Nearest to dont: good-natured, wept, looking, babble, adding, tomorrows, glue, settings,
# Nearest to back: effective, party, nice, underarms, indifferent, unprecedented, edible, outsmarted,
# Nearest to take: drenched, prop, interested, daily, securing, expectations, blinding, kick,
# Nearest to moment: grain, gulp, amount, thread, ration, chain, destinations, trusting,
# Nearest to capitol: problems, naked, conjure, awkward, tearing, honeysuckle, frightened, conducted,
# Nearest to like: dictate, yanks, oblivious, punctures, identified, power, rate, using,
# Nearest to think: luckily, lighten, forth, doomed, level, temper, traitor, salvage,
# Nearest to people: suffocate, molded, stinging, reduce, bothering, civilizing, roots, grandeur,
# Nearest to where: cloths, grill, uninjured, hideout, wept, hallway, perceived, condone,
# Nearest to they: resolving, foxface, urges, youd, shorts, leave, jabber, shouts,
# Nearest to over: corn, comparing, hauled, drip, radius, festivity, healer, levers,
# Average loss at step  32000 :  2.72263196367
# Average loss at step  34000 :  2.66574468243
# Average loss at step  36000 :  2.62179818624
# Average loss at step  38000 :  2.58263497621
# Average loss at step  40000 :  2.5516931169
# Nearest to UNK: nightmare, carve, rabid, liking, bottom, bowls, cloak, thefire,
# Nearest to never: couldve, ignored, explanations, disaster, remake, strikes, believes, showers,
# Nearest to more: frogs, fighter, strolling, uncomplaining, mumbles, yard, pokeweed, wears,
# Nearest to cato: groggy, west, personal, razor-sharp, halfway, overcome, half-dozen, dunks,
# Nearest to only: boxing, condenses, pursue, discover, contestants, reserved, maintain, addressed,
# Nearest to dont: good-natured, looking, wept, lunatic, babble, tomorrows, glue, winners,
# Nearest to back: nice, party, effective, underarms, envied, indifferent, forest, bolt,
# Nearest to take: prop, drenched, interested, securing, expectations, flee, topple, blinding,
# Nearest to moment: amount, thread, gulp, grain, fare, ration, chain, shifted,
# Nearest to capitol: problems, awkward, conjure, tearing, naked, blather, conducted, honeysuckle,
# Nearest to like: dictate, yanks, oblivious, identified, punctures, power, superior, mischievously,
# Nearest to think: luckily, lighten, level, forth, memory, traitor, temper, bodies,
# Nearest to people: suffocate, molded, stinging, bothering, civilizing, pink-and-white, reduce, roused,
# Nearest to where: cloths, grill, uninjured, hallway, perceived, accidents, hideout, flawless,
# Nearest to they: resolving, youd, urges, jabber, shorts, leave, undefeated, streams,
# Nearest to over: comparing, corn, drip, hauled, festivity, radius, imagine, levers,
# Average loss at step  42000 :  2.53412173694
# Average loss at step  44000 :  2.48844221389
# Average loss at step  46000 :  2.44541312569
# Average loss at step  48000 :  2.42632800174
# Average loss at step  50000 :  2.40803596598
# Nearest to UNK: nightmare, rabid, carve, liking, bottom, bowls, vines, thefire,
# Nearest to never: couldve, ignored, explanations, remake, disaster, strikes, puzzled, palms,
# Nearest to more: fighter, frogs, strolling, uncomplaining, disappeared, wears, yard, personally,
# Nearest to cato: west, razor-sharp, personal, halfway, groggy, unscathed, overcome, dunks,
# Nearest to only: boxing, condenses, contestants, discover, pursue, herbs, bought, complimentary,
# Nearest to dont: good-natured, wept, lunatic, babble, looking, tomorrows, winners, glue,
# Nearest to back: nice, indifferent, party, unprecedented, effective, underarms, envied, maces,
# Nearest to take: prop, drenched, interested, boiled, securing, splashing, arrived, plunge,
# Nearest to moment: fare, gulp, thread, trusting, shifted, ration, chain, destinations,
# Nearest to capitol: problems, awkward, conjure, tearing, sticking, naked, stream, blather,
# Nearest to like: dictate, punctures, identified, yanks, oblivious, swore, mischievously, power,
# Nearest to think: luckily, lighten, forth, level, traitor, dogging, flag, two-foot,
# Nearest to people: molded, suffocate, stinging, pink-and-white, civilizing, roused, evident, soak,
# Nearest to where: cloths, accidents, hallway, perceived, wept, grill, ails, drop-off,
# Nearest to they: resolving, leave, jabber, streams, shorts, urges, youd, hiking,
# Nearest to over: comparing, corn, drip, festivity, hauled, imagine, guarding, radius,
# Average loss at step  52000 :  2.37858857119
# Average loss at step  54000 :  2.37589049757
# Average loss at step  56000 :  2.33119019383
# Average loss at step  58000 :  2.31714951062
# Average loss at step  60000 :  2.29938115466
# Nearest to UNK: nightmare, rabid, liking, carve, bottom, cloak, source, thefire,
# Nearest to never: couldve, ignored, explanations, disaster, strikes, remake, showers, puzzled,
# Nearest to more: fighter, frogs, strolling, uncomplaining, disappeared, rethought, mumbles, personally,
# Nearest to cato: west, personal, halfway, razor-sharp, groggy, overcome, unscathed, dotted,
# Nearest to only: boxing, condenses, reserved, discover, complimentary, pursue, herbs, contestants,
# Nearest to dont: lunatic, good-natured, babble, wept, mean, looking, thing, winners,
# Nearest to back: nice, party, underarms, following, bolt, envied, unprecedented, indifferent,
# Nearest to take: prop, drenched, splashing, interested, securing, discover, boiled, demean,
# Nearest to moment: fare, shifted, thread, gulp, trusting, destinations, contacted, invisible,
# Nearest to capitol: problems, conjure, awkward, blather, stream, tearing, receive, money,
# Nearest to like: dictate, punctures, identified, yanks, swore, mischievously, stove, superior,
# Nearest to think: luckily, lighten, level, forth, feeble, dogging, despondency, flag,
# Nearest to people: molded, suffocate, pink-and-white, stinging, soak, civilizing, evident, bothering,
# Nearest to where: accidents, perceived, emanating, drop-off, grill, hallway, cloths, wept,
# Nearest to they: resolving, jabber, shorts, fades, leave, urges, plaintively, even,
# Nearest to over: corn, comparing, drip, imagine, hauled, festivity, guarding, apology,
# Average loss at step  62000 :  2.28373266533
# Average loss at step  64000 :  2.28062116659
# Average loss at step  66000 :  2.25307834315
# Average loss at step  68000 :  2.23230253348
# Average loss at step  70000 :  2.22867552513
# Nearest to UNK: nightmare, rabid, liking, carve, cloak, thefire, bottom, bowls,
# Nearest to never: couldve, ignored, disaster, puzzled, strikes, explanations, showers, palms,
# Nearest to more: fighter, frogs, disappeared, rethought, uncomplaining, mumbles, personally, strolling,
# Nearest to cato: west, groggy, halfway, razor-sharp, personal, luck, overcome, inhale,
# Nearest to only: boxing, condenses, complimentary, pursue, herbs, discover, require, bullet,
# Nearest to dont: lunatic, babble, mean, good-natured, forthcoming, wept, looking, shopkeepers,
# Nearest to back: party, nice, bolt, envied, underarms, unprecedented, following, effective,
# Nearest to take: drenched, prop, interested, boiled, splashing, demean, plunge, discover,
# Nearest to moment: fare, trusting, luring, shifted, contacted, thread, invisible, reminder,
# Nearest to capitol: problems, receive, stream, conjure, sticking, wealthier, blather, tearing,
# Nearest to like: dictate, punctures, swore, yanks, mischievously, identified, reproachful, superior,
# Nearest to think: luckily, feeble, lighten, level, forth, rung, despondency, salvage,
# Nearest to people: molded, pink-and-white, suffocate, stinging, civilizing, compete, soak, curiosity,
# Nearest to where: emanating, accidents, drop-off, uninjured, perceived, flawless, plunged, human-made,
# Nearest to they: resolving, shorts, unchecked, jabber, leave, wake, youd, spied,
# Nearest to over: comparing, corn, drip, guarding, imagine, festivity, hauled, apology,
# Average loss at step  72000 :  2.21560461283
# Average loss at step  74000 :  2.21977717352
# Average loss at step  76000 :  2.21127321386
# Average loss at step  78000 :  2.17775760677
# Average loss at step  80000 :  2.17234519404
# Nearest to UNK: nightmare, liking, rabid, carve, source, thefire, bottom, cloak,
# Nearest to never: couldve, disaster, strikes, puzzled, ignored, contrived, gorgeous-looking, showers,
# Nearest to more: fighter, frogs, uncomplaining, disappeared, strolling, rethought, personally, wears,
# Nearest to cato: west, personal, razor-sharp, groggy, advises, halfway, inhale, expectations,
# Nearest to only: boxing, complimentary, herbs, pursue, condenses, enlist, contestants, bullet,
# Nearest to dont: lunatic, babble, forthcoming, mean, dictate, good-natured, looking, misdirected,
# Nearest to back: party, bolt, nice, unprecedented, envied, hysterically, underarms, spears,
# Nearest to take: drenched, prop, boiled, interested, demean, splashing, plunge, securing,
# Nearest to moment: fare, shifted, trusting, delivered, luring, contacted, thread, suffer,
# Nearest to capitol: conjure, stream, awkward, receive, problems, backed, sticking, blather,
# Nearest to like: dictate, punctures, reproachful, identified, stove, swore, yanks, mischievously,
# Nearest to think: luckily, feeble, lighten, forth, level, two-foot, fuel, rung,
# Nearest to people: molded, pink-and-white, compete, suffocate, stinging, civilizing, curiosity, tabs,
# Nearest to where: emanating, accidents, drop-off, perceived, wept, uninjured, flawless, plunged,
# Nearest to they: resolving, flit, leave, thrilled, streams, spied, afoot, shorts,
# Nearest to over: comparing, drip, corn, imagine, festivity, guarding, apology, levers,
# Average loss at step  82000 :  2.16274204451
# Average loss at step  84000 :  2.16686829033
# Average loss at step  86000 :  2.16218099657
# Average loss at step  88000 :  2.13629063445
# Average loss at step  90000 :  2.12786050892
# Nearest to UNK: nightmare, rabid, liking, carve, thefire, cloak, bottom, bowls,
# Nearest to never: couldve, ignored, gorgeous-looking, strikes, puzzled, spirits, palms, showers,
# Nearest to more: fighter, frogs, uncomplaining, personally, rethought, disappeared, arise, strolling,
# Nearest to cato: west, personal, advises, razor-sharp, halfway, groggy, expectations, torchlight,
# Nearest to only: boxing, pursue, complimentary, warehouse, herbs, discover, uncommon, bullet,
# Nearest to dont: lunatic, forthcoming, babble, good-natured, winners, mean, orders, looking,
# Nearest to back: party, nice, bolt, following, underarms, effective, envied, woes,
# Nearest to take: drenched, prop, interested, demean, splashing, boiled, plunge, plunk,
# Nearest to moment: fare, trusting, shifted, luring, delivered, reminder, contacted, harvest,
# Nearest to capitol: stream, problems, conjure, receive, blather, awkward, unconsciousness, escapes,
# Nearest to like: dictate, reproachful, punctures, swore, mischievously, yanks, identified, stove,
# Nearest to think: luckily, lighten, feeble, forth, despondency, trusting, crew, cameraman,
# Nearest to people: pink-and-white, compete, molded, suffocate, civilizing, dreamed, curiosity, stinging,
# Nearest to where: emanating, accidents, perceived, plunged, flawless, drop-off, nightly, human-made,
# Nearest to they: resolving, spied, leave, plaintively, flit, jabber, youd, curls,
# Nearest to over: comparing, corn, drip, imagine, guarding, festivity, apology, levers,
# Average loss at step  92000 :  2.13884354791
# Average loss at step  94000 :  2.12831764519
# Average loss at step  96000 :  2.13333292583
# Average loss at step  98000 :  2.13385108411
# Average loss at step  100000 :  2.09725078881
# Nearest to UNK: nightmare, liking, rabid, carve, cloak, thefire, source, bowls,
# Nearest to never: couldve, puzzled, spirits, ignored, strikes, gorgeous-looking, disaster, contrived,
# Nearest to more: fighter, frogs, personally, uncomplaining, rethought, strolling, adult, revoked,
# Nearest to cato: west, advises, halfway, razor-sharp, luck, personal, inhale, expectations,
# Nearest to only: boxing, complimentary, pursue, enlist, manufactured, warehouse, discover, uncommon,
# Nearest to dont: lunatic, babble, forthcoming, winners, orders, good-natured, mean, opinion,
# Nearest to back: party, nice, underarms, envied, woes, outsmarted, unprecedented, effective,
# Nearest to take: drenched, demean, prop, interested, splashing, plunk, plunge, boiled,
# Nearest to moment: fare, trusting, shifted, delivered, luring, contacted, reminder, harvest,
# Nearest to capitol: stream, receive, problems, earlier, conjure, awkward, backed, blather,
# Nearest to like: dictate, punctures, reproachful, swore, identified, stove, mischievously, lacked,
# Nearest to think: luckily, feeble, forth, lighten, despondency, rung, salvage, cameraman,
# Nearest to people: pink-and-white, molded, compete, suffocate, civilizing, tabs, dreamed, curiosity,
# Nearest to where: emanating, accidents, perceived, drop-off, plunged, engaged, flawless, nightly,
# Nearest to they: unchecked, resolving, eighteen, plaintively, flit, jabber, know, hiking,
# Nearest to over: comparing, drip, corn, imagine, guarding, festivity, apology, hauled,
# Average loss at step  102000 :  2.11006272614
# Average loss at step  104000 :  2.09260357764
# Average loss at step  106000 :  2.11706929967
# Average loss at step  108000 :  2.11591162854
# Average loss at step  110000 :  2.09233341157
# Nearest to UNK: rabid, nightmare, liking, thefire, carve, cloak, source, openly,
# Nearest to never: couldve, puzzled, ignored, strikes, spirits, contrived, disaster, showers,
# Nearest to more: fighter, frogs, uncomplaining, personally, adult, strolling, disappeared, rethought,
# Nearest to cato: west, advises, luck, overhear, personal, razor-sharp, torchlight, withholding,
# Nearest to only: complimentary, pursue, boxing, enlist, discover, condenses, contestants, assembling,
# Nearest to dont: lunatic, forthcoming, good-natured, winners, babble, orders, added, mean,
# Nearest to back: party, indifferent, underarms, nice, following, woes, unprecedented, effective,
# Nearest to take: drenched, demean, prop, interested, splashing, boiled, accumulated, plunk,
# Nearest to moment: fare, trusting, shifted, reminder, delivered, luring, contacted, ration,
# Nearest to capitol: stream, receive, earlier, refusing, escapes, conjure, problems, blather,
# Nearest to like: dictate, swore, reproachful, identified, yanks, stove, lacked, punctures,
# Nearest to think: luckily, feeble, lighten, salvage, two-foot, forth, despondency, traitor,
# Nearest to people: pink-and-white, molded, compete, suffocate, civilizing, tabs, ladder, curiosity,
# Nearest to where: emanating, accidents, perceived, plunged, reenactments, nightly, human-made, drop-off,
# Nearest to they: flit, resolving, undefeated, recovered, jabber, youd, plaintively, curls,
# Nearest to over: comparing, imagine, corn, drip, festivity, apology, guarding, vengeance,
# Average loss at step  112000 :  2.0841718415
# Average loss at step  114000 :  2.0962951729
# Average loss at step  116000 :  2.08603217345
# Average loss at step  118000 :  2.10283546576
# Average loss at step  120000 :  2.09044581243
# Nearest to UNK: nightmare, rabid, liking, thefire, carve, cloak, scrubbed, bottom,
# Nearest to never: couldve, puzzled, gorgeous-looking, strikes, spirits, easier, contrived, palms,
# Nearest to more: fighter, frogs, uncomplaining, personally, disappeared, rethought, strolling, adult,
# Nearest to cato: west, advises, halfway, expectations, razor-sharp, luck, groggy, personal,
# Nearest to only: pursue, boxing, complimentary, herbs, reserved, warehouse, uncommon, discover,
# Nearest to dont: lunatic, good-natured, forthcoming, winners, babble, orders, thing, opinion,
# Nearest to back: following, party, woes, unprecedented, underarms, nice, outsmarted, hysterically,
# Nearest to take: drenched, demean, interested, boiled, splashing, prop, plunk, accumulated,
# Nearest to moment: fare, trusting, reminder, delivered, luring, shifted, harvest, contacted,
# Nearest to capitol: receive, stream, escapes, problems, backed, careers, refusing, fastens,
# Nearest to like: dictate, reproachful, mischievously, swore, identified, punctures, yanks, stove,
# Nearest to think: luckily, feeble, cameraman, forth, rung, lighten, crew, intend,
# Nearest to people: pink-and-white, compete, molded, suffocate, civilizing, tabs, ladder, curiosity,
# Nearest to where: emanating, accidents, engaged, human-made, perceived, plunged, flawless, drop-off,
# Nearest to they: have, flit, resolving, hiking, jabber, eighteen, defiance, plaintively,
# Nearest to over: comparing, drip, corn, imagine, guarding, festivity, laughter, apology,
# Average loss at step  122000 :  2.06769431996
# Average loss at step  124000 :  2.07991095525
# Average loss at step  126000 :  2.06670091954
# Average loss at step  128000 :  2.07839764521
# Average loss at step  130000 :  2.08804519629
# Nearest to UNK: nightmare, rabid, liking, cloak, carve, thefire, scrubbed, pond,
# Nearest to never: couldve, puzzled, contrived, easier, gorgeous-looking, caught, rooba, ignored,
# Nearest to more: fighter, frogs, personally, uncomplaining, strolling, rethought, disappeared, adult,
# Nearest to cato: west, advises, razor-sharp, groggy, halfway, possibly, luck, overhear,
# Nearest to only: pursue, boxing, complimentary, enlist, contestants, require, reserved, bullet,
# Nearest to dont: lunatic, forthcoming, babble, mean, winners, good-natured, relent, settings,
# Nearest to back: party, underarms, hysterically, unprecedented, woes, outsmarted, nice, bolt,
# Nearest to take: demean, drenched, interested, prop, boiled, plunk, splashing, ride,
# Nearest to moment: fare, trusting, delivered, luring, reminder, shifted, believably, foreign,
# Nearest to capitol: stream, receive, problems, blather, backed, earlier, wealthier, curved,
# Nearest to like: dictate, reproachful, punctures, swore, stove, identified, superior, idiots,
# Nearest to think: luckily, feeble, forth, lighten, photographs, overestimate, traitor, rung,
# Nearest to people: compete, pink-and-white, tabs, molded, civilizing, suffocate, ladder, dreamed,
# Nearest to where: emanating, accidents, plunged, ultimately, flawless, engaged, perceived, nightly,
# Nearest to they: sentence, even, have, liven, know, undefeated, afoot, plaintively,
# Nearest to over: comparing, corn, festivity, drip, apology, hauled, guarding, vengeance,
# Average loss at step  132000 :  2.06433757254
# Average loss at step  134000 :  2.06032895496
# Average loss at step  136000 :  2.06212223947
# Average loss at step  138000 :  2.0622435956
# Average loss at step  140000 :  2.07543108812
# Nearest to UNK: nightmare, rabid, liking, carve, cloak, thefire, scrubbed, source,
# Nearest to never: couldve, puzzled, contrived, palms, gorgeous-looking, easier, spirits, youd,
# Nearest to more: frogs, fighter, rethought, personally, uncomplaining, revoked, disappeared, adult,
# Nearest to cato: advises, maniacally, west, evils, groggy, luck, personal, razor-sharp,
# Nearest to only: pursue, boxing, complimentary, bullet, warehouse, herbs, reserved, uncommon,
# Nearest to dont: lunatic, good-natured, relent, mean, winners, forthcoming, babble, dictate,
# Nearest to back: woes, unprecedented, following, hysterically, nice, party, envied, bolt,
# Nearest to take: demean, interested, drenched, prop, splashing, plunk, boiled, plunge,
# Nearest to moment: fare, reminder, luring, delivered, trusting, shifted, contacted, harvest,
# Nearest to capitol: receive, fastens, careers, problems, stream, thanked, curved, refusing,
# Nearest to like: dictate, reproachful, swore, identified, stove, punctures, underrate, lacked,
# Nearest to think: luckily, feeble, forth, two-foot, traitor, salvage, cameraman, overestimate,
# Nearest to people: compete, pink-and-white, molded, curiosity, suffocate, tabs, dreamed, ladder,
# Nearest to where: emanating, plunged, accidents, engaged, perceived, ultimately, flawless, reenactments,
# Nearest to they: curls, afoot, resolving, eighteen, hiking, flit, liven, racking,
# Nearest to over: comparing, corn, drip, festivity, apology, laughter, hauled, guarding,
# Average loss at step  142000 :  2.06525138831
# Average loss at step  144000 :  2.04742107794
# Average loss at step  146000 :  2.05790014818
# Average loss at step  148000 :  2.05451809692
# Average loss at step  150000 :  2.05719515824
# Nearest to UNK: nightmare, rabid, liking, carve, cloak, thefire, source, pond,
# Nearest to never: couldve, puzzled, contrived, caught, palms, spirits, stabbing, easier,
# Nearest to more: fighter, frogs, rethought, personally, adult, uncomplaining, revoked, strolling,
# Nearest to cato: west, overhear, personal, luck, advises, expectations, evils, groggy,
# Nearest to only: pursue, complimentary, boxing, expected, herbs, require, contestants, uncommon,
# Nearest to dont: lunatic, good-natured, forthcoming, wept, dictate, babble, plaintively, winners,
# Nearest to back: underarms, hysterically, envied, woes, bolt, party, nice, unprecedented,
# Nearest to take: demean, drenched, interested, plunk, boiled, splashing, accumulated, prop,
# Nearest to moment: fare, delivered, reminder, luring, shifted, trusting, contacted, harvest,
# Nearest to capitol: receive, backed, earlier, escapes, curved, belonged, stream, wealthier,
# Nearest to like: dictate, reproachful, swore, punctures, identified, lacked, stove, mischievously,
# Nearest to think: luckily, feeble, salvage, level, lighten, traitor, forth, two-foot,
# Nearest to people: compete, pink-and-white, tabs, molded, dreamed, curiosity, ladder, civilizing,
# Nearest to where: engaged, emanating, accidents, plunged, human-made, wept, perceived, ultimately,
# Nearest to they: resolving, plaintively, crouch, curls, hiking, flit, afoot, didnt,
# Nearest to over: comparing, corn, drip, festivity, starchy, vengeance, guarding, savage,
# Average loss at step  152000 :  2.06847507557
# Average loss at step  154000 :  2.0358354488
# Average loss at step  156000 :  2.04574672934
# Average loss at step  158000 :  2.03842500618
# Average loss at step  160000 :  2.05793090528
# Nearest to UNK: rabid, nightmare, liking, carve, thefire, cloak, pond, scrubbed,
# Nearest to never: couldve, puzzled, palms, easier, faulty, quilting, ignored, ever,
# Nearest to more: frogs, fighter, rethought, uncomplaining, personally, revoked, disappeared, adult,
# Nearest to cato: west, advises, luck, personal, evils, overhear, generously, expectations,
# Nearest to only: pursue, complimentary, reserved, uncommon, contestants, boxing, adjacent, discover,
# Nearest to dont: lunatic, winners, babble, opinion, forthcoming, good-natured, glue, backs,
# Nearest to back: hysterically, nice, underarms, woes, flatly, following, unprecedented, darkens,
# Nearest to take: demean, drenched, interested, plunk, splashing, inflict, accumulated, prop,
# Nearest to moment: fare, luring, delivered, reminder, shifted, trusting, harvest, enters,
# Nearest to capitol: receive, stream, since, conscious, backed, belonged, curved, careers,
# Nearest to like: dictate, reproachful, stove, swore, identified, mischievously, underrate, punctures,
# Nearest to think: luckily, feeble, salvage, two-foot, forth, contestants, rung, intimidate,
# Nearest to people: compete, pink-and-white, tabs, molded, dreamed, ladder, wrestled, civilizing,
# Nearest to where: emanating, engaged, human-made, accidents, perceived, plunged, flawless, ultimately,
# Nearest to they: plaintively, crouch, flit, resolving, racking, sentence, spied, undefeated,
# Nearest to over: comparing, festivity, drip, corn, imagine, apology, guarding, decorate,
# Average loss at step  162000 :  2.07036235198
# Average loss at step  164000 :  2.040151645
# Average loss at step  166000 :  2.03331288865
# Average loss at step  168000 :  2.04020227078
# Average loss at step  170000 :  2.03905474797
# Nearest to UNK: rabid, nightmare, liking, thefire, carve, scrubbed, cloak, bowls,
# Nearest to never: couldve, puzzled, youd, contrived, showers, easier, palms, caught,
# Nearest to more: frogs, fighter, rethought, personally, revoked, uncomplaining, strolling, unrecognizable,
# Nearest to cato: advises, luck, west, maniacally, personal, expectations, overhear, inhale,
# Nearest to only: pursue, complimentary, require, herbs, boxing, enlist, adjacent, warehouse,
# Nearest to dont: lunatic, mean, winners, disgust, babble, opinion, forthcoming, aback,
# Nearest to back: woes, nice, hysterically, unprecedented, darkens, indifferent, envied, underarms,
# Nearest to take: demean, drenched, interested, splashing, plunk, prop, accumulated, load,
# Nearest to moment: delivered, fare, reminder, luring, trusting, shifted, harvest, dancing,
# Nearest to capitol: receive, conscious, backed, problems, belonged, since, earlier, stream,
# Nearest to like: dictate, reproachful, swore, punctures, identified, underrate, stove, mischievously,
# Nearest to think: luckily, feeble, forth, level, two-foot, cameraman, intend, dance,
# Nearest to people: compete, pink-and-white, tabs, molded, dreamed, curiosity, ladder, held,
# Nearest to where: emanating, plunged, reenactments, engaged, ultimately, accidents, human-made, flawless,
# Nearest to they: liven, resolving, crouch, demonstrations, hiking, even, afoot, flit,
# Nearest to over: comparing, corn, drip, laughter, festivity, guarding, apology, imagine,
# Average loss at step  172000 :  2.05192772529
# Average loss at step  174000 :  2.04630962738
# Average loss at step  176000 :  2.02692210725
# Average loss at step  178000 :  2.03434556127
# Average loss at step  180000 :  2.02956365815
# Nearest to UNK: rabid, nightmare, liking, thefire, carve, scrubbed, cloak, green-and-silver,
# Nearest to never: couldve, puzzled, youd, caught, contrived, palms, gorgeous-looking, gang,
# Nearest to more: fighter, frogs, rethought, personally, uncomplaining, unrecognizable, revoked, strolling,
# Nearest to cato: west, luck, advises, haymitch, overhear, inhale, personal, blows,
# Nearest to only: pursue, complimentary, adjacent, boxing, assembling, herbs, grown-ups, bullet,
# Nearest to dont: lunatic, good-natured, forthcoming, aback, mean, winners, babble, misdirected,
# Nearest to back: woes, following, indifferent, hysterically, unprecedented, bolt, party, unsettled,
# Nearest to take: drenched, demean, interested, accumulated, plunk, splashing, boiled, inflict,
# Nearest to moment: luring, reminder, shifted, fare, delivered, trusting, suffer, believably,
# Nearest to capitol: conscious, receive, belonged, curved, backed, remembers, problems, owing,
# Nearest to like: dictate, reproachful, swore, lacked, punctures, strangled, stove, identified,
# Nearest to think: luckily, feeble, forth, two-foot, level, salvage, lighten, dogging,
# Nearest to people: compete, tabs, pink-and-white, molded, dreamed, curiosity, civilizing, suffocate,
# Nearest to where: human-made, emanating, plunged, accidents, readyto, ultimately, reenactments, wept,
# Nearest to they: curls, resolving, afoot, unchecked, flit, hiking, eighteen, fades,
# Nearest to over: comparing, drip, corn, festivity, apology, guarding, laughter, vengeance,
# Average loss at step  182000 :  2.04167547485
# Average loss at step  184000 :  2.04318464321
# Average loss at step  186000 :  2.0231083093
# Average loss at step  188000 :  2.0191573424
# Average loss at step  190000 :  2.02668264228
# Nearest to UNK: rabid, nightmare, liking, thefire, scrubbed, cloak, carve, haggling,
# Nearest to never: couldve, puzzled, contrived, palms, easier, stabbing, gang, quilting,
# Nearest to more: fighter, frogs, uncomplaining, personally, rethought, revoked, strolling, transmitted,
# Nearest to cato: luck, advises, west, blows, expectations, personal, overhear, maniacally,
# Nearest to only: pursue, complimentary, adjacent, bullet, boxing, assembling, herbs, paths,
# Nearest to dont: lunatic, babble, good-natured, forthcoming, winners, mean, opinion, wrestled,
# Nearest to back: woes, unprecedented, nice, following, outsmarted, hysterically, bolt, howling,
# Nearest to take: demean, interested, drenched, splashing, plunk, boiled, checks, require,
# Nearest to moment: luring, reminder, fare, delivered, trusting, contacted, shifted, harvest,
# Nearest to capitol: earlier, receive, conscious, curved, belonged, stream, speedy, admirers,
# Nearest to like: dictate, lacked, reproachful, punctures, swore, stove, underrate, identified,
# Nearest to think: luckily, feeble, two-foot, intend, salvage, lighten, masks, level,
# Nearest to people: compete, tabs, pink-and-white, molded, curiosity, dreamed, suffocate, held,
# Nearest to where: emanating, plunged, human-made, accidents, flawless, ultimately, wept, perceived,
# Nearest to they: spied, unchecked, even, resolving, flit, curls, crouch, splash,
# Nearest to over: comparing, drip, corn, apology, utter, festivity, guarding, vengeance,
# Average loss at step  192000 :  2.02116066307
# Average loss at step  194000 :  2.04561023101
# Average loss at step  196000 :  2.04172439814
# Average loss at step  198000 :  2.0058203586

# %%
with open('hungergame-list.p', 'wb') as fopen:
    pickle.dump(list(reverse_dictionary.values()), fopen)

# %%
with open('hungergame-vector.p', 'wb') as fopen:
    pickle.dump(final_embeddings, fopen)
