# %%
import re
import tensorflow as tf
import numpy as np
import time
import os
import collections
import random
import time
import nltk
import pickle

# %%
def clearstring(string):
    string = re.sub('[^A-Za-z\- ]+', '', string)
    string = string.split(' ')
    string = filter(None, string)
    string = [y.strip() for y in string]
    return [y.lower() for y in string if len(y) > 3 and y.find('nbsp') < 0]

def build_dataset(words, n_words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(n_words - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        index = dictionary.get(word, 0)
        if index == 0:  # dictionary['UNK']
            unk_count += 1
        data.append(index)
    count[0][1] = unk_count
    reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reversed_dictionary

data_index = 0

# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    global data
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1  # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    if data_index + span > len(data):
        data_index = 0
    buffer.extend(data[data_index:data_index + span])
    data_index += span
    for i in range(batch_size // num_skips):
        context_words = [w for w in range(span) if w != skip_window]
        words_to_use = random.sample(context_words, num_skips)
        for j, context_word in enumerate(words_to_use):
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[context_word]
        if data_index == len(data):
            for word in data[:span]:
                buffer.append(word)
            data_index = span
        else:
            buffer.append(data[data_index])
            data_index += 1
    # Backtrack a little bit to avoid skipping words in the end of a batch
    data_index = (data_index + len(data) - span) % len(data)
    return batch, labels

# %%
with open('books/HalfBloodPrince.txt', 'r',encoding = "ISO-8859-1") as fopen:
    vocabulary = clearstring(' '.join(nltk.word_tokenize(fopen.read())))
print('example 10 words:',vocabulary[:10])
print('size corpus:',len(vocabulary))
vocabulary_size = len(list(set(vocabulary)))
print('size of unique words:',vocabulary_size)
dimension = 128
skip_window = 1
num_skips = 2
batch_size = 64
location = os.getcwd()
# Out:
# example 10 words: ['nearing', 'midnight', 'prime', 'minister', 'sitting', 'alone', 'office', 'reading', 'long', 'memo']
# size corpus: 98994
# size of unique words: 10682

# %%
data, count, dictionary, reverse_dictionary = build_dataset(vocabulary,vocabulary_size)
del vocabulary  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])
# Out:
# Most common words (+UNK) [['UNK', 1], ('harry', 2771), ('said', 2450), ('that', 2123), ('with', 1072)]
# Sample data [4227, 1529, 140, 103, 188, 221, 155, 1050, 97, 5090] ['nearing', 'midnight', 'prime', 'minister', 'sitting', 'alone', 'office', 'reading', 'long', 'memo']

# %%
valid_size = 16
valid_window = 100
valid_examples = np.random.choice(valid_window, valid_size, replace=False)

# %%
graph = tf.Graph()

with graph.as_default():

    train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Ops and variables pinned to the CPU because of missing GPU implementation
    with tf.device('/cpu:0'):
        embeddings = tf.Variable(tf.random_uniform([vocabulary_size, dimension], -1.0, 1.0))
        embed = tf.nn.embedding_lookup(embeddings, train_inputs)
        nce_weights = tf.Variable(tf.truncated_normal([vocabulary_size, dimension],
                                                      stddev=1.0 / np.sqrt(dimension)))
        nce_biases = tf.Variable(tf.zeros([vocabulary_size]))
        loss = tf.reduce_mean(tf.nn.nce_loss(weights=nce_weights,
                                             biases=nce_biases,
                                             labels=train_labels,
                                             inputs=embed,
                                             num_sampled=batch_size / 2,
                                             num_classes=vocabulary_size))
        optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

        # Compute the cosine similarity between minibatch examples and all embeddings.
        norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
        normalized_embeddings = embeddings / norm
        valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
        similarity = tf.matmul(valid_embeddings, normalized_embeddings, transpose_b=True)
        init = tf.global_variables_initializer()

num_steps = 200000

# %%
with tf.Session(graph=graph) as session:
    init.run()
    print('Initialized')

    average_loss = 0
    for step in range(num_steps):
        batch_inputs, batch_labels = generate_batch(batch_size, num_skips, skip_window)
        feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

        _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += loss_val

        if step % 2000 == 0:
            if step > 0:
                average_loss /= 2000
            print('Average loss at step ', step, ': ', average_loss)
            average_loss = 0

        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8  # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                log_str = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log_str = '%s %s,' % (log_str, close_word)
                print(log_str)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  120.179695129
# Nearest to very: induce, happy, fishy, approached, impervious, concealed, daily, footprints,
# Nearest to only: booklist, vibrant, highly, prowling, unwise, closing, thus, queen,
# Nearest to have: harpies, start-of-term, striding, wheezy, suggested, gloating, roaring, palm,
# Nearest to malfoy: dried-up, answering, markings, dunno, intact, parted, unreadable, exploits,
# Nearest to tell: half-blood, conductor, teaches, evidently, sectum-sempra, beat, holds, constant,
# Nearest to voice: drove, sky-high, appar-ition, comical, recounted, nicknames, lurked, conga,
# Nearest to about: preoccupied, inclination, repaired, induce, hopefully, sherry, reworded, anymon,
# Nearest to know: slanted, malfoyd, compensations, damp, ceasing, untruthfully, malfoy-is-a-death-eater, prac-,
# Nearest to through: commentator, ruff, looked, enjoyment, send-off, arry, stubbs, bobbing,
# Nearest to voldemort: teaching, cancelled, modify, obscuring, squad, ankle-deep, calculated, attempt,
# Nearest to death: barking, bonder, tangle, flustered, shabby-looking, gormless, lower, darkness,
# Nearest to seemed: ancestors, mun-dungus, bat-bogey, suitcase, rich, puffs, familiar, shoppers,
# Nearest to from: predecessor, mon-ster, hermi-one, outside, cheering, inert, shrank, cubicle,
# Nearest to never: di-rected, frightens, upside-down, clapped, inclination, bones, hokeys, headed,
# Nearest to than: snorting, cowardly, frenzied, steep, deluded, impedi, movement, justice,
# Nearest to where: erectly, tobias, worst, expired, unwilling, frowned, reek-ing, inflicted,
# Average loss at step  2000 :  42.3527684288
# Average loss at step  4000 :  14.5528313073
# Average loss at step  6000 :  7.8342447536
# Average loss at step  8000 :  5.54252574825
# Average loss at step  10000 :  4.69095448363
# Nearest to very: induce, fishy, happy, work, sipping, couldn, action, shrieked,
# Nearest to only: booklist, affair, itself, welcoming, absolutely, awestruck, difference, ownership,
# Nearest to have: knife, suggested, that, legs, they, explanation, purpose, smashing,
# Nearest to malfoy: answering, dried-up, deliver, dumbledore, discomfited, grils, markings, snakelike,
# Nearest to tell: half-blood, hear, beat, evidently, conductor, anymore, teaches, whiskey,
# Nearest to voice: cottage, appar-ition, mcgonagall, drove, despised, said, slanted, comical,
# Nearest to about: assurances, intently, preoccupied, repaired, marks, induce, swill, inclination,
# Nearest to know: aware, honest, swore, that, malfoyd, purplish, compensations, knew,
# Nearest to through: ruff, staggered, amelia, speck, bobbing, spill, upon, commentator,
# Nearest to voldemort: teaching, cancelled, please, attempt, squad, hallucination, phosphorescent, dumbledore,
# Nearest to death: lower, shabby-looking, volde-mort, blaze, infatuation, hole, flustered, gormless,
# Nearest to seemed: anticipated, bat-bogey, intended, puffs, jewels, would, where, must,
# Nearest to from: spinning, shrank, cars, buck, broke, concentrating, outside, predecessor,
# Nearest to never: di-rected, linked, nice, upside-down, scornfully, rustle, negligently, strictly,
# Nearest to than: snorting, cowardly, disappearing, sobbed, deluded, frenzied, impedi, bang,
# Nearest to where: erectly, slumping, paused, stepped, frowned, seemed, goblei, left,
# Average loss at step  12000 :  4.2059878329
# Average loss at step  14000 :  3.96113126671
# Average loss at step  16000 :  3.82697795272
# Average loss at step  18000 :  3.69980423713
# Average loss at step  20000 :  3.59490205801
# Nearest to very: induce, sipping, lend, fishy, couldn, reading, sur-rounded, disappeared,
# Nearest to only: booklist, affair, prejudiced, itself, foresaw, comically, awestruck, seeming,
# Nearest to have: purpose, smashing, knife, wheezy, pasted, disguise, legs, sorted,
# Nearest to malfoy: dried-up, answering, discomfited, deliver, grils, scrimgeour, tentatively, onlookers,
# Nearest to tell: half-blood, hear, whiskey, beat, teaches, find, evidently, told,
# Nearest to voice: mcgonagall, appar-ition, slanted, biting, drove, comical, emanating, despised,
# Nearest to about: assurances, intently, swill, marks, inhaled, useful, inclination, relishing,
# Nearest to know: aware, malfoyd, nowadays, honest, knew, proceedings, swore, untruthfully,
# Nearest to through: staggered, ruff, speck, spill, amelia, bobbing, bella, defense,
# Nearest to voldemort: cancelled, phosphorescent, teaching, hallucination, squad, wanting, ankle-deep, clumsily,
# Nearest to death: lower, shabby-looking, barking, infatuation, volde-mort, support, blaze, bonder,
# Nearest to seemed: anticipated, puffs, jewels, bat-bogey, would, flaming, bear, cheerfully,
# Nearest to from: shrank, spinning, closer, predecessor, unmistakable, exasperation, unprovoked, buck,
# Nearest to never: di-rected, negligently, linked, upside-down, alley, exams, finality, myrtle,
# Nearest to than: snorting, cowardly, deluded, disappearing, frenzied, sobbed, reserving, charges,
# Nearest to where: slumping, erectly, goblei, rougher, paused, stepped, frowned, dolores,
# Average loss at step  22000 :  3.52578915191
# Average loss at step  24000 :  3.47022294641
# Average loss at step  26000 :  3.38061025131
# Average loss at step  28000 :  3.35485616922
# Average loss at step  30000 :  3.29474854624
# Nearest to very: induce, lend, sipping, fishy, considering, sur-rounded, pamphlets, action,
# Nearest to only: prejudiced, booklist, foresaw, affair, itself, comically, wasted, relationship,
# Nearest to have: sorted, pasted, smashing, deposit, purpose, embraced, alley, yawning,
# Nearest to malfoy: dried-up, answering, discomfited, deliver, raving, grils, disbelieving, madness,
# Nearest to tell: half-blood, hear, whiskey, beat, teaches, mostc, hurt, wedding,
# Nearest to voice: mcgonagall, biting, appar-ition, realms, slanted, drove, emanating, wag-ging,
# Nearest to about: assurances, intently, useful, dursley, nagini, inhaled, marks, interesting,
# Nearest to know: aware, malfoyd, nowadays, honest, wrong, nonstop, slanted, impress,
# Nearest to through: staggered, speck, ruff, amelia, spill, bobbing, organ, defense,
# Nearest to voldemort: cancelled, teaching, phosphorescent, wanting, clumsily, hallucination, girlfriends, playacting,
# Nearest to death: lower, shabby-looking, support, barking, bonder, volde-mort, infatuation, vector,
# Nearest to seemed: anticipated, puffs, jewels, tentacle, bat-bogey, flaming, patience, bearings,
# Nearest to from: shrank, unprovoked, dif-ficult, spinning, exasperation, dismissal, predecessor, closer,
# Nearest to never: di-rected, negligently, dark-ness, selling, alley, appeal-ing, exams, myrtle,
# Nearest to than: snorting, deluded, cowardly, frenzied, disappearing, starving, reserving, affronted,
# Nearest to where: rougher, goblei, slumping, dittany, erectly, clumsily, absence, tobias,
# Average loss at step  32000 :  3.22505728877
# Average loss at step  34000 :  3.22981076026
# Average loss at step  36000 :  3.15602542233
# Average loss at step  38000 :  3.12749143893
# Average loss at step  40000 :  3.10838507742
# Nearest to very: lend, induce, sipping, fishy, considering, depart, sur-rounded, automati-cally,
# Nearest to only: prejudiced, booklist, foresaw, itself, comically, affair, wilhout, wasted,
# Nearest to have: sorted, smashing, embraced, purpose, pasted, mutilate, fletcher, deposit,
# Nearest to malfoy: answering, dried-up, discomfited, raving, deliver, disbelieving, madness, tussle,
# Nearest to tell: half-blood, whiskey, hear, mostc, wedding, squashy, beat, separates,
# Nearest to voice: mcgonagall, realms, somewhat, wag-ging, emanating, appar-ition, weapons, biting,
# Nearest to about: assurances, intently, the-, useful, nagini, inhaled, dursley, straw-colored,
# Nearest to know: aware, malfoyd, nowadays, wrong, nonstop, honest, slanted, flare,
# Nearest to through: speck, staggered, amelia, ruff, spill, organ, weasley-ish, bobbing,
# Nearest to voldemort: cancelled, phosphorescent, wanting, teaching, clumsily, hallucination, playacting, squad,
# Nearest to death: shabby-looking, lower, support, bonder, infatuation, blaze, vector, wound,
# Nearest to seemed: puffs, anticipated, patience, jewels, bearings, flaming, bat-bogey, tentacle,
# Nearest to from: unprovoked, exasperation, closing, predecessor, twelve-year-old, shrank, spinning, dismissal,
# Nearest to never: di-rected, negligently, alley, dark-ness, selling, appeal-ing, greeting, exams,
# Nearest to than: deluded, cowardly, snorting, frenzied, starving, affronted, reserving, fronted,
# Nearest to where: goblei, rougher, slumping, clumsily, dittany, erectly, s-bend, sybill,
# Average loss at step  42000 :  3.06403649056
# Average loss at step  44000 :  3.02928800601
# Average loss at step  46000 :  3.02364887989
# Average loss at step  48000 :  2.96089247376
# Average loss at step  50000 :  2.95863304031
# Nearest to very: lend, sipping, depart, induce, considering, fishy, automati-cally, wheezing,
# Nearest to only: prejudiced, booklist, foresaw, queen, pockets, wilhout, comically, affair,
# Nearest to have: embraced, sorted, smashing, pasted, alley, mutilate, stretches, mood,
# Nearest to malfoy: discomfited, answering, dried-up, raving, deliver, normally, disbelieving, madness,
# Nearest to tell: half-blood, mostc, wedding, whiskey, imagine, squashy, gorilla, breeding,
# Nearest to voice: mcgonagall, weapons, realms, wag-ging, somewhat, endured, emanating, appar-ition,
# Nearest to about: assurances, intently, useful, the-, nagini, earnest, inhaled, dursley,
# Nearest to know: nowadays, aware, malfoyd, wrong, nonsense, slanted, assuming, ceasing,
# Nearest to through: speck, amelia, staggered, organ, spill, ruff, weasley-ish, lecturing,
# Nearest to voldemort: cancelled, phosphorescent, playacting, wanting, clumsily, teaching, ei-ther, mudblood,
# Nearest to death: shabby-looking, lower, support, bonder, wound, infatuation, frowned, jump,
# Nearest to seemed: anticipated, puffs, patience, bat-bogey, jewels, tentacle, jinxed, bearings,
# Nearest to from: unprovoked, dismissal, exasperation, predecessor, closing, closer, cream, shrank,
# Nearest to never: di-rected, dark-ness, negligently, alley, selling, appeal-ing, greeting, publicity,
# Nearest to than: cowardly, deluded, snorting, affronted, defeated-looking, frenzied, role, starving,
# Nearest to where: rougher, goblei, slumping, clumsily, tobias, sybill, s-bend, interpreted,
# Average loss at step  52000 :  2.9451361444
# Average loss at step  54000 :  2.89634295559
# Average loss at step  56000 :  2.88819694602
# Average loss at step  58000 :  2.88167024618
# Average loss at step  60000 :  2.82552863365
# Nearest to very: lend, depart, considering, sipping, fishy, spared, induce, automati-cally,
# Nearest to only: prejudiced, foresaw, comically, booklist, pockets, motioned, wilhout, whomever,
# Nearest to have: sorted, embraced, pasted, purpose, mood, dreamlike, smashing, event,
# Nearest to malfoy: discomfited, dried-up, raving, answering, deliver, normally, disbelieving, scrimgeour,
# Nearest to tell: half-blood, mostc, squashy, wedding, imagine, breeding, gorilla, whiskey,
# Nearest to voice: mcgonagall, realms, wag-ging, weapons, gestured, intake, mountains, appar-ition,
# Nearest to about: the-, assurances, useful, intently, earnest, dursley, inhaled, interesting,
# Nearest to know: nowadays, malfoyd, aware, nonsense, flare, tobias, nonstop, assuming,
# Nearest to through: amelia, speck, organ, weasley-ish, ruff, extensive, spill, staggered,
# Nearest to voldemort: cancelled, phosphorescent, wanting, playacting, ei-ther, clumsily, teaching, mudblood,
# Nearest to death: shabby-looking, support, lower, bonder, wound, tendency, frowned, jump,
# Nearest to seemed: anticipated, puffs, bearings, patience, jinxed, flaming, jewels, aching,
# Nearest to from: unprovoked, shrank, exasperation, twelve-year-old, dismissal, closing, graffitied, predecessor,
# Nearest to never: di-rected, dark-ness, negligently, greeting, alley, selling, publicity, heir,
# Nearest to than: cowardly, deluded, snorting, defeated-looking, frenzied, affronted, role, secretive,
# Nearest to where: goblei, rougher, reality, exercised, abruptly, sybill, clumsily, dittany,
# Average loss at step  62000 :  2.85492189372
# Average loss at step  64000 :  2.80212688231
# Average loss at step  66000 :  2.77033920282
# Average loss at step  68000 :  2.80759987193
# Average loss at step  70000 :  2.73210986263
# Nearest to very: lend, depart, considering, fishy, automati-cally, alarmed, tasty, spared,
# Nearest to only: prejudiced, foresaw, motioned, drink, booklist, comically, clung, wilhout,
# Nearest to have: sorted, mutilate, mood, event, embraced, pasted, purpose, encumbered,
# Nearest to malfoy: discomfited, answering, raving, dried-up, normally, deliver, disbelieving, grils,
# Nearest to tell: half-blood, mostc, wedding, breeding, gorilla, imagine, hear, great-great-grandmother,
# Nearest to voice: realms, mcgonagall, wag-ging, gestured, twist, weapons, captaincy, biting,
# Nearest to about: assurances, inhaled, useful, intently, the-, dursley, peppermint, nagini,
# Nearest to know: nowadays, assuming, nonsense, malfoyd, aware, compensations, armed, ceasing,
# Nearest to through: amelia, speck, organ, plunging, ruff, extensive, real, lots,
# Nearest to voldemort: cancelled, phosphorescent, playacting, wanting, ei-ther, advance, hallucination, clumsily,
# Nearest to death: shabby-looking, support, lower, bonder, wound, tendency, vector, eaters,
# Nearest to seemed: anticipated, puffs, bearings, patience, jinxed, jewels, package, flaming,
# Nearest to from: unprovoked, closing, shrank, dismissal, exasperation, cream, graffitied, predecessor,
# Nearest to never: di-rected, greeting, negligently, dark-ness, heir, publicity, selling, sightings,
# Nearest to than: cowardly, deluded, snorting, frenzied, defeated-looking, compelled, secretive, secateurs,
# Nearest to where: goblei, rougher, abruptly, reality, dittany, lagging, exercised, sybill,
# Average loss at step  72000 :  2.73763079542
# Average loss at step  74000 :  2.73931400532
# Average loss at step  76000 :  2.70087049603
# Average loss at step  78000 :  2.68578644753
# Average loss at step  80000 :  2.69726799029
# Nearest to very: lend, depart, fishy, automati-cally, spared, considering, tasty, petrificus,
# Nearest to only: prejudiced, foresaw, tawny, drink, wilhout, motioned, pockets, booklist,
# Nearest to have: sorted, event, pasted, embraced, purpose, mood, sentry, mutilate,
# Nearest to malfoy: raving, discomfited, normally, answering, dried-up, cracks, deliver, receive,
# Nearest to tell: half-blood, mostc, breeding, wedding, imagine, confirmed, groggily, great-great-grandmother,
# Nearest to voice: realms, wag-ging, gestured, emanating, weapons, captaincy, idea, twist,
# Nearest to about: intently, assurances, useful, the-, nagini, inhaled, deficient, forcefully,
# Nearest to know: nowadays, malfoyd, aware, nonsense, assuming, ceasing, flare, hermione,
# Nearest to through: speck, amelia, organ, extensive, plunging, real, disastrous, across,
# Nearest to voldemort: phosphorescent, cancelled, wanting, playacting, ei-ther, clumsily, mudblood, advance,
# Nearest to death: shabby-looking, support, lower, bonder, vector, jump, frowned, engraving,
# Nearest to seemed: anticipated, jinxed, bearings, puffs, patience, jewels, aching, patiently,
# Nearest to from: unprovoked, underestimated, suppers, unmistakable, exasperation, dismissal, flittered, pelting,
# Nearest to never: negligently, dark-ness, di-rected, greeting, selling, heir, publicity, sightings,
# Nearest to than: deluded, cowardly, snorting, defeated-looking, fronted, secateurs, bundled, compelled,
# Nearest to where: goblei, rougher, abruptly, reality, sybill, dittany, exercised, clumsily,
# Average loss at step  82000 :  2.64286334831
# Average loss at step  84000 :  2.65451175624
# Average loss at step  86000 :  2.64973825812
# Average loss at step  88000 :  2.61146261865
# Average loss at step  90000 :  2.62149968469
# Nearest to very: lend, depart, automati-cally, fishy, considering, alarmed, sipping, wheezing,
# Nearest to only: prejudiced, drink, motioned, foresaw, wilhout, tawny, spend, aspect,
# Nearest to have: sorted, yawning, purpose, pasted, mood, mutilate, event, tang,
# Nearest to malfoy: discomfited, raving, answering, dried-up, normally, cracks, confess, deliver,
# Nearest to tell: half-blood, breeding, mostc, wedding, imagine, unimpressed, groggily, dreadful,
# Nearest to voice: wag-ging, weapons, waxy, gestured, realms, captaincy, twist, biting,
# Nearest to about: intently, useful, the-, nagini, assurances, inhaled, peppermint, deficient,
# Nearest to know: nowadays, nonsense, flare, malfoyd, tobias, aware, compensations, poker,
# Nearest to through: speck, organ, amelia, real, across, plunging, stairs, extensive,
# Nearest to voldemort: phosphorescent, playacting, cancelled, ei-ther, brooding, wanting, precautions, mudblood,
# Nearest to death: shabby-looking, support, lower, bonder, jump, frowned, engraving, eaters,
# Nearest to seemed: anticipated, jinxed, bearings, puffs, patience, aching, jewels, patiently,
# Nearest to from: underestimated, unprovoked, cream, closing, unmistakable, clothing, suppers, shouldnta,
# Nearest to never: heir, negligently, greeting, have, dark-ness, di-rected, selling, appeal-ing,
# Nearest to than: cowardly, deluded, defeated-looking, snorting, role, fronted, secateurs, impostor,
# Nearest to where: goblei, exercised, rougher, abruptly, dittany, sticking, zigzagging, sybill,
# Average loss at step  92000 :  2.61380171108
# Average loss at step  94000 :  2.57052056539
# Average loss at step  96000 :  2.6076737389
# Average loss at step  98000 :  2.55887676299
# Average loss at step  100000 :  2.55192895091
# Nearest to very: lend, depart, spared, fishy, automati-cally, considering, tasty, alarmed,
# Nearest to only: prejudiced, foresaw, tawny, sprig, motioned, wilhout, drink, aspect,
# Nearest to have: sorted, pasted, embraced, mutilate, purpose, event, fletcher, sentry,
# Nearest to malfoy: raving, normally, discomfited, dried-up, answering, bluntly, cracks, disbelieving,
# Nearest to tell: half-blood, breeding, mostc, wedding, unimpressed, confirmed, imagine, genius,
# Nearest to voice: wag-ging, captaincy, realms, weapons, gestured, twist, shunpike, waxy,
# Nearest to about: assurances, useful, the-, intently, comforted, forcefully, unusual, dursley,
# Nearest to know: nowadays, nonsense, malfoyd, compensations, assuming, sup-ported, poker, knew,
# Nearest to through: speck, amelia, real, organ, across, plunging, lots, stairs,
# Nearest to voldemort: phosphorescent, playacting, ei-ther, prediction, cancelled, brooding, wanting, draco,
# Nearest to death: shabby-looking, support, bonder, pro-tecting, eaters, lower, quick-thinking, inexpert,
# Nearest to seemed: anticipated, puffs, jinxed, aching, bearings, nudged, patience, jewels,
# Nearest to from: unprovoked, underestimated, unmistakable, predecessor, suppers, exasperation, clothing, closing,
# Nearest to never: heir, greeting, negligently, collector, di-rected, sightings, dark-ness, selling,
# Nearest to than: cowardly, deluded, defeated-looking, compelled, portentously, impostor, secateurs, role,
# Nearest to where: goblei, abruptly, dittany, exercised, reality, lagging, sybill, zigzagging,
# Average loss at step  102000 :  2.58541245025
# Average loss at step  104000 :  2.52254356766
# Average loss at step  106000 :  2.52990198404
# Average loss at step  108000 :  2.54214121419
# Average loss at step  110000 :  2.49060418236
# Nearest to very: depart, spared, automati-cally, lend, tasty, fishy, considering, alarmed,
# Nearest to only: prejudiced, motioned, foresaw, drink, sprig, wilhout, aspect, whim,
# Nearest to have: sorted, event, mutilate, smashing, pasted, embraced, deposit, purpose,
# Nearest to malfoy: discomfited, normally, raving, answering, dried-up, cracks, deliver, confess,
# Nearest to tell: half-blood, breeding, mostc, wedding, unimpressed, imagine, sleek, dreadful,
# Nearest to voice: wag-ging, realms, twist, gestured, weapons, captaincy, transport, shunpike,
# Nearest to about: inhaled, assurances, forcefully, dursley, peppermint, comforted, intently, nagini,
# Nearest to know: nowadays, nonsense, compensations, flare, malfoyd, tobias, assuming, sup-ported,
# Nearest to through: speck, organ, lots, amelia, real, across, plunging, weasley-ish,
# Nearest to voldemort: phosphorescent, playacting, ei-ther, clumsily, wanting, procuring, scornfully, advance,
# Nearest to death: shabby-looking, support, inexpert, eaters, frowned, lower, bonder, quick-thinking,
# Nearest to seemed: puffs, bearings, jinxed, anticipated, aching, nudged, jewels, shielding,
# Nearest to from: unprovoked, underestimated, suppers, hushed, twist, shouldnta, exasperation, flittered,
# Nearest to never: heir, greeting, negligently, sightings, di-rected, publicity, wails, apologies,
# Nearest to than: cowardly, deluded, defeated-looking, impostor, incan-tations, bundled, guessed, role,
# Nearest to where: goblei, exercised, abruptly, dittany, lagging, zigzagging, sticking, reality,
# Average loss at step  112000 :  2.50228874362
# Average loss at step  114000 :  2.51575320518
# Average loss at step  116000 :  2.46503803623
# Average loss at step  118000 :  2.49113866961
# Average loss at step  120000 :  2.48985898387
# Nearest to very: depart, lend, spared, petrificus, automati-cally, fishy, considering, two-seater,
# Nearest to only: motioned, prejudiced, wilhout, tawny, sprig, drink, pockets, foresaw,
# Nearest to have: event, sorted, mutilate, purpose, embraced, dreamlike, mood, deposit,
# Nearest to malfoy: normally, raving, discomfited, dried-up, answering, cracks, approve, buzzing,
# Nearest to tell: breeding, half-blood, proof, wedding, mostc, confirmed, imagine, unimpressed,
# Nearest to voice: wag-ging, twist, captaincy, realms, represent, weapons, gestured, idea,
# Nearest to about: forcefully, assurances, nagini, deficient, glamour, outshine, inhaled, unusual,
# Nearest to know: nonsense, nowadays, malfoyd, assuming, flare, ceasing, compensations, hermione,
# Nearest to through: speck, lots, amelia, organ, stairs, real, plunging, across,
# Nearest to voldemort: playacting, phosphorescent, prediction, sicker, ei-ther, cancelled, ankle-deep, precautions,
# Nearest to death: shabby-looking, support, quick-thinking, eaters, inexpert, bonder, engraving, gormless,
# Nearest to seemed: bearings, jinxed, puffs, anticipated, aching, shielding, patience, platform,
# Nearest to from: underestimated, unprovoked, suppers, flittered, interested, closing, twist, unmistakable,
# Nearest to never: negligently, heir, greeting, selling, sightings, grip, skin, collector,
# Nearest to than: deluded, cowardly, defeated-looking, guessed, bundled, secateurs, fronted, impostor,
# Nearest to where: goblei, abruptly, lagging, fairies, exercised, guarding, dittany, rougher,
# Average loss at step  122000 :  2.44862452185
# Average loss at step  124000 :  2.46312792331
# Average loss at step  126000 :  2.47138180387
# Average loss at step  128000 :  2.42163226926
# Average loss at step  130000 :  2.47345637
# Nearest to very: lend, depart, automati-cally, spared, considering, fishy, gashes, tasty,
# Nearest to only: prejudiced, drink, motioned, aspect, tawny, wilhout, sprig, whim,
# Nearest to have: sorted, they, mutilate, event, never, informed, crest, pasted,
# Nearest to malfoy: raving, normally, answering, discomfited, dried-up, buzzing, deliver, bluntly,
# Nearest to tell: breeding, confirmed, half-blood, mostc, unyielding, proof, imagine, genius,
# Nearest to voice: twist, wag-ging, waxy, weapons, idea, captaincy, represent, shouldnt,
# Nearest to about: assurances, deficient, intently, forcefully, peppermint, nagini, the-, glamour,
# Nearest to know: nonsense, compensations, nowadays, sup-ported, ceasing, dreads, world-class, flare,
# Nearest to through: speck, real, lots, amelia, organ, contentment, plunging, across,
# Nearest to voldemort: prediction, ei-ther, phosphorescent, sicker, playacting, brooding, cancelled, procuring,
# Nearest to death: shabby-looking, inexpert, support, quick-thinking, eaters, frowned, engraving, jump,
# Nearest to seemed: anticipated, bearings, puffs, jinxed, platform, aching, shielding, deck,
# Nearest to from: underestimated, unprovoked, predecessor, interested, twist, hushed, flittered, closing,
# Nearest to never: heir, negligently, have, sightings, greeting, selling, wails, skin,
# Nearest to than: deluded, cowardly, guessed, defeated-looking, secateurs, bundled, impostor, incan-tations,
# Nearest to where: goblei, abruptly, fairies, sticking, youngest, zigzagging, chalk, plants,
# Average loss at step  132000 :  2.41471030623
# Average loss at step  134000 :  2.42086545816
# Average loss at step  136000 :  2.45547512496
# Average loss at step  138000 :  2.39046573669
# Average loss at step  140000 :  2.41756522033
# Nearest to very: lend, spared, automati-cally, depart, gashes, petrificus, tasty, fishy,
# Nearest to only: motioned, sprig, prejudiced, drink, aspect, whim, vibrate, wilhout,
# Nearest to have: they, sorted, mutilate, sentry, never, normally, dreamlike, embraced,
# Nearest to malfoy: raving, dried-up, discomfited, buzzing, normally, bluntly, receive, answering,
# Nearest to tell: breeding, half-blood, imagine, unyielding, wedding, confirmed, mostc, proof,
# Nearest to voice: twist, wag-ging, represent, weapons, deliberately, realms, gestured, shunpike,
# Nearest to about: peppermint, intently, assurances, nagini, deficient, forcefully, comforted, the-,
# Nearest to know: nowadays, nonsense, compensations, sup-ported, tobias, punished, flare, assuming,
# Nearest to through: speck, real, amelia, organ, stairs, lots, contentment, across,
# Nearest to voldemort: phosphorescent, ei-ther, prediction, playacting, sicker, tasted, precautions, under-stood,
# Nearest to death: shabby-looking, quick-thinking, inexpert, conta-minate, frowned, support, eaters, engraving,
# Nearest to seemed: puffs, jinxed, anticipated, bearings, shielding, aching, deck, nudged,
# Nearest to from: underestimated, unprovoked, hushed, predecessor, flittered, closing, dismissal, twist,
# Nearest to never: heir, negligently, have, greeting, sightings, selling, di-rected, collector,
# Nearest to than: deluded, cowardly, guessed, defeated-looking, impostor, portentously, secateurs, compelled,
# Nearest to where: goblei, exercised, zigzagging, sticking, guarding, abruptly, reality, youngest,
# Average loss at step  142000 :  2.42711773506
# Average loss at step  144000 :  2.38078848428
# Average loss at step  146000 :  2.39784763211
# Average loss at step  148000 :  2.41269604078
# Average loss at step  150000 :  2.36077362335
# Nearest to very: lend, automati-cally, spared, alarmed, depart, gashes, unusually, two-and-a-half,
# Nearest to only: motioned, prejudiced, sprig, drink, foresaw, clung, aspect, whim,
# Nearest to have: sorted, event, they, mutilate, purpose, despairingly, jubilantly, advisory,
# Nearest to malfoy: normally, raving, dried-up, discomfited, buzzing, answering, bluntly, confess,
# Nearest to tell: breeding, imagine, half-blood, proof, wedding, teaches, unyielding, confirmed,
# Nearest to voice: wag-ging, twist, weapons, represent, transport, captaincy, shouldnt, idea,
# Nearest to about: dursley, assurances, forcefully, inhaled, comforted, intently, glamour, nagini,
# Nearest to know: nowadays, nonsense, flare, assuming, tobias, sup-ported, compensations, hermione,
# Nearest to through: speck, real, amelia, organ, lots, plunging, disastrous, stubbs,
# Nearest to voldemort: ei-ther, prediction, phosphorescent, playacting, sicker, tasted, procuring, purring,
# Nearest to death: shabby-looking, conta-minate, support, quick-thinking, engraving, gormless, bonder, inexpert,
# Nearest to seemed: bearings, puffs, anticipated, deck, aching, opportu-nity, shielding, patience,
# Nearest to from: underestimated, flittered, twist, shrank, hushed, unprovoked, shouldnta, cosseted,
# Nearest to never: negligently, heir, greeting, collector, sightings, selling, have, purest,
# Nearest to than: deluded, cowardly, guessed, defeated-looking, portentously, secateurs, incan-tations, impostor,
# Nearest to where: goblei, zigzagging, fairies, sticking, guarding, youngest, dittany, abruptly,
# Average loss at step  152000 :  2.39738587129
# Average loss at step  154000 :  2.39605124477
# Average loss at step  156000 :  2.36416405857
# Average loss at step  158000 :  2.37157634735
# Average loss at step  160000 :  2.37210591355
# Nearest to very: spared, automati-cally, depart, lend, gashes, disconcerted, alarmed, two-seater,
# Nearest to only: prejudiced, motioned, whim, drink, clung, dumbstruck, tawny, aspect,
# Nearest to have: they, sorted, event, deposit, never, mutilate, normally, employees,
# Nearest to malfoy: raving, normally, discomfited, buzzing, approve, named, receive, regretting,
# Nearest to tell: breeding, unyielding, half-blood, corpses, confirmed, opinions, mostc, unimpressed,
# Nearest to voice: wag-ging, twist, captaincy, represent, gestured, transport, third-eldest, weapons,
# Nearest to about: forcefully, outshine, assurances, unusual, nagini, comforted, dursley, inhaled,
# Nearest to know: hermione, nowadays, compensations, nonsense, flare, assuming, tobias, sup-ported,
# Nearest to through: speck, amelia, across, organ, lots, real, contentment, stubbs,
# Nearest to voldemort: sicker, phosphorescent, advance, prediction, playacting, procuring, snowing, ei-ther,
# Nearest to death: shabby-looking, inexpert, conta-minate, quick-thinking, engraving, raspberry, support, scarless,
# Nearest to seemed: bearings, puffs, jinxed, aching, shielding, patience, deck, anticipated,
# Nearest to from: underestimated, unprovoked, punching, twist, flittered, other-wise, predecessor, shouldnta,
# Nearest to never: heir, negligently, collector, selling, have, sightings, greeting, skin,
# Nearest to than: deluded, cowardly, guessed, defeated-looking, secateurs, portentously, incan-tations, allowing,
# Nearest to where: goblei, guarding, abruptly, fairies, zigzagging, exercised, sybill, grand-son,
# Average loss at step  162000 :  2.3498401106
# Average loss at step  164000 :  2.40092294008
# Average loss at step  166000 :  2.34029785925
# Average loss at step  168000 :  2.34847494125
# Average loss at step  170000 :  2.38196036524
# Nearest to very: lend, automati-cally, spared, depart, gashes, plaintively, disconcerted, two-seater,
# Nearest to only: prejudiced, motioned, drink, whim, aspect, tawny, pockets, dumbstruck,
# Nearest to have: they, event, mutilate, purpose, never, sorted, smashing, mood,
# Nearest to malfoy: raving, normally, discomfited, dried-up, answering, buzzing, smirking, resigned-looking,
# Nearest to tell: breeding, unyielding, uest, confirmed, half-blood, opinions, proof, imagine,
# Nearest to voice: wag-ging, represent, captaincy, weapons, twist, won-won, waxy, barty,
# Nearest to about: forcefully, assurances, nagini, glamour, intently, deficient, peppermint, inhaled,
# Nearest to know: compensations, nonsense, hermione, sup-ported, world-class, flare, nowadays, dreads,
# Nearest to through: speck, amelia, across, lots, organ, extensive, contentment, real,
# Nearest to voldemort: advance, prediction, playacting, sicker, phosphorescent, ei-ther, scornfully, brooding,
# Nearest to death: shabby-looking, conta-minate, quick-thinking, strengthened, inexpert, scarless, support, engraving,
# Nearest to seemed: bearings, puffs, aching, deck, jinxed, standing, puppet, anticipated,
# Nearest to from: underestimated, unprovoked, twist, shouldnta, other-wise, hushed, suppers, flittered,
# Nearest to never: heir, have, negligently, sightings, selling, collector, buckled, greeting,
# Nearest to than: deluded, guessed, cowardly, defeated-looking, incan-tations, impostor, chucked, compelled,
# Nearest to where: goblei, guarding, abruptly, fairies, youngest, exercised, zigzagging, neither,
# Average loss at step  172000 :  2.32116426605
# Average loss at step  174000 :  2.36251851732
# Average loss at step  176000 :  2.36039586884
# Average loss at step  178000 :  2.31615774545
# Average loss at step  180000 :  2.33861104667
# Nearest to very: depart, spared, lend, automati-cally, alarmed, petrificus, unusually, fishy,
# Nearest to only: prejudiced, whim, motioned, drink, aspect, sprig, sheets, dumbstruck,
# Nearest to have: they, sorted, mutilate, advisory, never, event, wind, purpose,
# Nearest to malfoy: dried-up, raving, normally, buzzing, discomfited, disbelieving, answering, receive,
# Nearest to tell: breeding, unyielding, abou, confirmed, imagine, unimpressed, half-blood, course,
# Nearest to voice: twist, wag-ging, represent, captaincy, deliberately, weapons, lurked, realms,
# Nearest to about: deficient, assurances, forcefully, outshine, peppermint, intently, whiled, glamour,
# Nearest to know: sup-ported, nowadays, nonsense, flare, hermione, ceasing, compensations, tobias,
# Nearest to through: speck, lots, hall, amelia, rules, across, disastrous, organ,
# Nearest to voldemort: sicker, phosphorescent, prediction, advance, playacting, procuring, raving, ei-ther,
# Nearest to death: shabby-looking, conta-minate, inexpert, strengthened, engraving, scarless, raspberry, utter,
# Nearest to seemed: jinxed, puffs, anticipated, aching, nudged, puppet, deck, third-eldest,
# Nearest to from: underestimated, twist, hushed, predecessor, unmistakable, unprovoked, flittered, dresser,
# Nearest to never: heir, negligently, sightings, selling, greeting, have, collector, red-and-gold-clad,
# Nearest to than: deluded, cowardly, guessed, assured, defeated-looking, incan-tations, bundled, impostor,
# Nearest to where: goblei, guarding, abruptly, sticking, zigzagging, fairies, neither, youngest,
# Average loss at step  182000 :  2.35114185521
# Average loss at step  184000 :  2.30800324979
# Average loss at step  186000 :  2.33810658163
# Average loss at step  188000 :  2.34109566507
# Average loss at step  190000 :  2.31081699568
# Nearest to very: lend, depart, automati-cally, spared, alarmed, disconcerted, gashes, two-seater,
# Nearest to only: motioned, prejudiced, sprig, whim, aspect, dumbstruck, pockets, clung,
# Nearest to have: sorted, event, they, mutilate, purpose, normally, give, smashing,
# Nearest to malfoy: normally, raving, buzzing, discomfited, answering, dried-up, smirking, named,
# Nearest to tell: breeding, unyielding, abou, half-blood, unimpressed, proof, confirmed, opinions,
# Nearest to voice: twist, captaincy, weapons, wag-ging, idea, deliberately, waxy, intake,
# Nearest to about: deficient, forcefully, glamour, peppermint, intently, nagini, dursley, feebly,
# Nearest to know: compensations, nonsense, nowadays, sup-ported, that, ceasing, tobias, flare,
# Nearest to through: speck, plunging, contentment, across, amelia, early, rules, weasley-ish,
# Nearest to voldemort: sicker, phosphorescent, playacting, advance, prediction, procuring, raving, ei-ther,
# Nearest to death: shabby-looking, conta-minate, inexpert, quick-thinking, raspberry, scarless, engraving, gormless,
# Nearest to seemed: puffs, bearings, shielding, jinxed, puppet, anticipated, unlikely, deck,
# Nearest to from: twist, underestimated, unprovoked, shrank, punching, graffitied, hushed, suppers,
# Nearest to never: heir, negligently, collector, di-rected, greeting, sightings, have, selling,
# Nearest to than: deluded, cowardly, defeated-looking, guessed, impostor, incan-tations, revoked, forget,
# Nearest to where: goblei, guarding, abruptly, reality, neither, zigzagging, sticking, fairies,
# Average loss at step  192000 :  2.33581276321
# Average loss at step  194000 :  2.31930258992
# Average loss at step  196000 :  2.30138353711
# Average loss at step  198000 :  2.35729946288

# %%
with open('halfblood-list.p', 'wb') as fopen:
    pickle.dump(list(reverse_dictionary.values()), fopen)

# %%
with open('halfblood-vector.p', 'wb') as fopen:
    pickle.dump(final_embeddings, fopen)
